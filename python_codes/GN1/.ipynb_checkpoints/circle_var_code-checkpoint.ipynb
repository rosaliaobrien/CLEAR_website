# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

def cirsize(r):
    return 10-r

#note: must use radii not reff values
GN1data = pd.read_csv('/Users/rosaliaobrien/research/website_data/GN1.cat', sep=' ')
GN1data['radii'] = cirsize(GN1data['kr'])
#print(GN1data)

# %%
def circle_var(gidn, radius, field):
    text1="var circle = L.circle(gid{0}, ".format(gidn)
    
    text2="{\n\
color: 'red',\n\
fillOpacity: 0,\n\
opacity: 5,\n"

    text3="radius:{0}".format(radius)
    
    text4="}).addTo(map);"
    
    text5="circle.bindPopup('gid#{0}: ' + '<a href=".format(gidn)
    
    text6='"bio_pages/{1}_{0}.html" target="_blank">'.format(gidn, field)
    
    text7="BIO PAGE</a>')\n\
circle.on('mouseover', function (e) {"
    
    text8="circlegid='{0}';\n\
document.getElementById('circle_tracker').innerHTML=circlegid".format(gidn)
    
    text9="});\n\
circle.on('mouseout', function (e) {\n\
circlegid='Move cursor over object';\n\
document.getElementById('circle_tracker').innerHTML=circlegid\n\
});"
    
    return text1 + text2 + text3 + text4 + text5 +text6 + text7 + text8 + text9

# %%
gid=GN1data['ids']
radii=GN1data['radii']


for i, r in zip(gid, radii):
        variables=circle_var(i,r,'GN1')
        print(variables)
# Out:
# var circle = L.circle(gid35921, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.54}).addTo(map);circle.bindPopup('gid#35921: ' + '<a href="bio_pages/GN1_35921.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35921';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36114, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36114: ' + '<a href="bio_pages/GN1_36114.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36114';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36203, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.08}).addTo(map);circle.bindPopup('gid#36203: ' + '<a href="bio_pages/GN1_36203.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36203';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36243, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36243: ' + '<a href="bio_pages/GN1_36243.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36243';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36303, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36303: ' + '<a href="bio_pages/GN1_36303.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36303';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36382, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.3}).addTo(map);circle.bindPopup('gid#36382: ' + '<a href="bio_pages/GN1_36382.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36382';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36420, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36420: ' + '<a href="bio_pages/GN1_36420.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36420';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36435, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36435: ' + '<a href="bio_pages/GN1_36435.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36435';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36456, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36456: ' + '<a href="bio_pages/GN1_36456.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36456';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36514, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.4}).addTo(map);circle.bindPopup('gid#36514: ' + '<a href="bio_pages/GN1_36514.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36514';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36521, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36521: ' + '<a href="bio_pages/GN1_36521.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36521';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36556, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.04}).addTo(map);circle.bindPopup('gid#36556: ' + '<a href="bio_pages/GN1_36556.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36556';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36577, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.24}).addTo(map);circle.bindPopup('gid#36577: ' + '<a href="bio_pages/GN1_36577.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36577';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36596, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36596: ' + '<a href="bio_pages/GN1_36596.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36596';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36613, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36613: ' + '<a href="bio_pages/GN1_36613.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36613';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36623, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.06}).addTo(map);circle.bindPopup('gid#36623: ' + '<a href="bio_pages/GN1_36623.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36623';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36651, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.05}).addTo(map);circle.bindPopup('gid#36651: ' + '<a href="bio_pages/GN1_36651.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36651';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36663, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.4}).addTo(map);circle.bindPopup('gid#36663: ' + '<a href="bio_pages/GN1_36663.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36663';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36681, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36681: ' + '<a href="bio_pages/GN1_36681.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36681';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36717, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:4.33}).addTo(map);circle.bindPopup('gid#36717: ' + '<a href="bio_pages/GN1_36717.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36717';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36733, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.41}).addTo(map);circle.bindPopup('gid#36733: ' + '<a href="bio_pages/GN1_36733.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36733';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36735, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:4.89}).addTo(map);circle.bindPopup('gid#36735: ' + '<a href="bio_pages/GN1_36735.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36735';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36736, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.65}).addTo(map);circle.bindPopup('gid#36736: ' + '<a href="bio_pages/GN1_36736.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36736';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36738, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.59}).addTo(map);circle.bindPopup('gid#36738: ' + '<a href="bio_pages/GN1_36738.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36738';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36761, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:2.87}).addTo(map);circle.bindPopup('gid#36761: ' + '<a href="bio_pages/GN1_36761.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36761';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36773, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.97}).addTo(map);circle.bindPopup('gid#36773: ' + '<a href="bio_pages/GN1_36773.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36773';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36783, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36783: ' + '<a href="bio_pages/GN1_36783.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36783';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36786, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36786: ' + '<a href="bio_pages/GN1_36786.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36786';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36788, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.69}).addTo(map);circle.bindPopup('gid#36788: ' + '<a href="bio_pages/GN1_36788.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36788';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36795, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.25}).addTo(map);circle.bindPopup('gid#36795: ' + '<a href="bio_pages/GN1_36795.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36795';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36808, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36808: ' + '<a href="bio_pages/GN1_36808.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36808';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36809, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36809: ' + '<a href="bio_pages/GN1_36809.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36809';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36812, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.97}).addTo(map);circle.bindPopup('gid#36812: ' + '<a href="bio_pages/GN1_36812.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36812';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36813, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.86}).addTo(map);circle.bindPopup('gid#36813: ' + '<a href="bio_pages/GN1_36813.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36813';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36856, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:4.91}).addTo(map);circle.bindPopup('gid#36856: ' + '<a href="bio_pages/GN1_36856.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36856';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36860, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.16}).addTo(map);circle.bindPopup('gid#36860: ' + '<a href="bio_pages/GN1_36860.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36860';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36880, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.99}).addTo(map);circle.bindPopup('gid#36880: ' + '<a href="bio_pages/GN1_36880.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36880';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36889, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36889: ' + '<a href="bio_pages/GN1_36889.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36889';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36890, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:4.84}).addTo(map);circle.bindPopup('gid#36890: ' + '<a href="bio_pages/GN1_36890.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36890';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36900, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.279999999999999}).addTo(map);circle.bindPopup('gid#36900: ' + '<a href="bio_pages/GN1_36900.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36900';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36917, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36917: ' + '<a href="bio_pages/GN1_36917.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36917';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36920, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.12}).addTo(map);circle.bindPopup('gid#36920: ' + '<a href="bio_pages/GN1_36920.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36920';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36926, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:4.13}).addTo(map);circle.bindPopup('gid#36926: ' + '<a href="bio_pages/GN1_36926.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36926';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36928, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.18}).addTo(map);circle.bindPopup('gid#36928: ' + '<a href="bio_pages/GN1_36928.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36928';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36936, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.29}).addTo(map);circle.bindPopup('gid#36936: ' + '<a href="bio_pages/GN1_36936.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36936';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36968, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#36968: ' + '<a href="bio_pages/GN1_36968.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36968';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36985, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:2.6799999999999997}).addTo(map);circle.bindPopup('gid#36985: ' + '<a href="bio_pages/GN1_36985.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36985';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37006, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37006: ' + '<a href="bio_pages/GN1_37006.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37006';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37018, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.08}).addTo(map);circle.bindPopup('gid#37018: ' + '<a href="bio_pages/GN1_37018.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37018';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37019, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37019: ' + '<a href="bio_pages/GN1_37019.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37019';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37023, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.15}).addTo(map);circle.bindPopup('gid#37023: ' + '<a href="bio_pages/GN1_37023.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37023';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37031, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.24}).addTo(map);circle.bindPopup('gid#37031: ' + '<a href="bio_pages/GN1_37031.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37031';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37037, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.43}).addTo(map);circle.bindPopup('gid#37037: ' + '<a href="bio_pages/GN1_37037.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37037';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37052, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37052: ' + '<a href="bio_pages/GN1_37052.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37052';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37053, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.69}).addTo(map);circle.bindPopup('gid#37053: ' + '<a href="bio_pages/GN1_37053.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37053';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37060, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.49}).addTo(map);circle.bindPopup('gid#37060: ' + '<a href="bio_pages/GN1_37060.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37060';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37065, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.18}).addTo(map);circle.bindPopup('gid#37065: ' + '<a href="bio_pages/GN1_37065.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37065';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37067, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37067: ' + '<a href="bio_pages/GN1_37067.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37067';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37072, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37072: ' + '<a href="bio_pages/GN1_37072.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37072';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37074, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37074: ' + '<a href="bio_pages/GN1_37074.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37074';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37076, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.29}).addTo(map);circle.bindPopup('gid#37076: ' + '<a href="bio_pages/GN1_37076.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37076';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37096, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.33}).addTo(map);circle.bindPopup('gid#37096: ' + '<a href="bio_pages/GN1_37096.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37096';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37102, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.1}).addTo(map);circle.bindPopup('gid#37102: ' + '<a href="bio_pages/GN1_37102.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37102';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37135, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:3.4000000000000004}).addTo(map);circle.bindPopup('gid#37135: ' + '<a href="bio_pages/GN1_37135.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37135';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37156, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:2.2300000000000004}).addTo(map);circle.bindPopup('gid#37156: ' + '<a href="bio_pages/GN1_37156.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37156';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37167, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37167: ' + '<a href="bio_pages/GN1_37167.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37167';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37170, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37170: ' + '<a href="bio_pages/GN1_37170.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37170';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37177, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37177: ' + '<a href="bio_pages/GN1_37177.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37177';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37192, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37192: ' + '<a href="bio_pages/GN1_37192.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37192';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37193, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37193: ' + '<a href="bio_pages/GN1_37193.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37193';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37204, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.78}).addTo(map);circle.bindPopup('gid#37204: ' + '<a href="bio_pages/GN1_37204.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37204';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37206, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.09}).addTo(map);circle.bindPopup('gid#37206: ' + '<a href="bio_pages/GN1_37206.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37206';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37214, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37214: ' + '<a href="bio_pages/GN1_37214.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37214';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37217, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.3100000000000005}).addTo(map);circle.bindPopup('gid#37217: ' + '<a href="bio_pages/GN1_37217.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37217';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37220, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:1.8200000000000003}).addTo(map);circle.bindPopup('gid#37220: ' + '<a href="bio_pages/GN1_37220.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37220';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37233, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.3}).addTo(map);circle.bindPopup('gid#37233: ' + '<a href="bio_pages/GN1_37233.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37233';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37237, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:4.07}).addTo(map);circle.bindPopup('gid#37237: ' + '<a href="bio_pages/GN1_37237.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37237';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37243, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:4.82}).addTo(map);circle.bindPopup('gid#37243: ' + '<a href="bio_pages/GN1_37243.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37243';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37247, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.74}).addTo(map);circle.bindPopup('gid#37247: ' + '<a href="bio_pages/GN1_37247.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37247';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37253, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.53}).addTo(map);circle.bindPopup('gid#37253: ' + '<a href="bio_pages/GN1_37253.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37253';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37256, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.2}).addTo(map);circle.bindPopup('gid#37256: ' + '<a href="bio_pages/GN1_37256.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37256';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37258, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:4.83}).addTo(map);circle.bindPopup('gid#37258: ' + '<a href="bio_pages/GN1_37258.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37258';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37261, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.94}).addTo(map);circle.bindPopup('gid#37261: ' + '<a href="bio_pages/GN1_37261.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37261';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37269, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.75}).addTo(map);circle.bindPopup('gid#37269: ' + '<a href="bio_pages/GN1_37269.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37269';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37271, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37271: ' + '<a href="bio_pages/GN1_37271.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37271';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37272, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.62}).addTo(map);circle.bindPopup('gid#37272: ' + '<a href="bio_pages/GN1_37272.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37272';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37276, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.85}).addTo(map);circle.bindPopup('gid#37276: ' + '<a href="bio_pages/GN1_37276.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37276';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37279, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.84}).addTo(map);circle.bindPopup('gid#37279: ' + '<a href="bio_pages/GN1_37279.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37279';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37282, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.02}).addTo(map);circle.bindPopup('gid#37282: ' + '<a href="bio_pages/GN1_37282.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37282';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37288, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.05}).addTo(map);circle.bindPopup('gid#37288: ' + '<a href="bio_pages/GN1_37288.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37288';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37295, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37295: ' + '<a href="bio_pages/GN1_37295.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37295';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37306, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.77}).addTo(map);circle.bindPopup('gid#37306: ' + '<a href="bio_pages/GN1_37306.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37306';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37307, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.4399999999999995}).addTo(map);circle.bindPopup('gid#37307: ' + '<a href="bio_pages/GN1_37307.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37307';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37314, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37314: ' + '<a href="bio_pages/GN1_37314.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37314';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37316, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.94}).addTo(map);circle.bindPopup('gid#37316: ' + '<a href="bio_pages/GN1_37316.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37316';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37330, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37330: ' + '<a href="bio_pages/GN1_37330.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37330';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37340, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37340: ' + '<a href="bio_pages/GN1_37340.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37340';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37343, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37343: ' + '<a href="bio_pages/GN1_37343.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37343';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37347, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:4.36}).addTo(map);circle.bindPopup('gid#37347: ' + '<a href="bio_pages/GN1_37347.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37347';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37349, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.83}).addTo(map);circle.bindPopup('gid#37349: ' + '<a href="bio_pages/GN1_37349.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37349';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37363, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37363: ' + '<a href="bio_pages/GN1_37363.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37363';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37366, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.87}).addTo(map);circle.bindPopup('gid#37366: ' + '<a href="bio_pages/GN1_37366.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37366';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37371, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.43}).addTo(map);circle.bindPopup('gid#37371: ' + '<a href="bio_pages/GN1_37371.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37371';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37375, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#37375: ' + '<a href="bio_pages/GN1_37375.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37375';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# ...
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38121, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#38121: ' + '<a href="bio_pages/GN1_38121.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38121';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38123, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.4399999999999995}).addTo(map);circle.bindPopup('gid#38123: ' + '<a href="bio_pages/GN1_38123.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38123';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38125, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.72}).addTo(map);circle.bindPopup('gid#38125: ' + '<a href="bio_pages/GN1_38125.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38125';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38126, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.69}).addTo(map);circle.bindPopup('gid#38126: ' + '<a href="bio_pages/GN1_38126.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38126';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38127, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.3}).addTo(map);circle.bindPopup('gid#38127: ' + '<a href="bio_pages/GN1_38127.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38127';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38130, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:3.25}).addTo(map);circle.bindPopup('gid#38130: ' + '<a href="bio_pages/GN1_38130.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38130';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38134, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.91}).addTo(map);circle.bindPopup('gid#38134: ' + '<a href="bio_pages/GN1_38134.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38134';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38138, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:3.41}).addTo(map);circle.bindPopup('gid#38138: ' + '<a href="bio_pages/GN1_38138.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38138';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38139, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.88}).addTo(map);circle.bindPopup('gid#38139: ' + '<a href="bio_pages/GN1_38139.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38139';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38140, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.77}).addTo(map);circle.bindPopup('gid#38140: ' + '<a href="bio_pages/GN1_38140.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38140';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38143, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:4.8}).addTo(map);circle.bindPopup('gid#38143: ' + '<a href="bio_pages/GN1_38143.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38143';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38149, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:4.19}).addTo(map);circle.bindPopup('gid#38149: ' + '<a href="bio_pages/GN1_38149.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38149';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38154, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:4.45}).addTo(map);circle.bindPopup('gid#38154: ' + '<a href="bio_pages/GN1_38154.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38154';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38155, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.15}).addTo(map);circle.bindPopup('gid#38155: ' + '<a href="bio_pages/GN1_38155.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38155';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38159, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.84}).addTo(map);circle.bindPopup('gid#38159: ' + '<a href="bio_pages/GN1_38159.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38159';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38160, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:3.34}).addTo(map);circle.bindPopup('gid#38160: ' + '<a href="bio_pages/GN1_38160.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38160';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38163, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.37}).addTo(map);circle.bindPopup('gid#38163: ' + '<a href="bio_pages/GN1_38163.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38163';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38173, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:3.7800000000000002}).addTo(map);circle.bindPopup('gid#38173: ' + '<a href="bio_pages/GN1_38173.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38173';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38179, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.029999999999999}).addTo(map);circle.bindPopup('gid#38179: ' + '<a href="bio_pages/GN1_38179.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38179';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38180, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.39}).addTo(map);circle.bindPopup('gid#38180: ' + '<a href="bio_pages/GN1_38180.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38180';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38184, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.74}).addTo(map);circle.bindPopup('gid#38184: ' + '<a href="bio_pages/GN1_38184.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38184';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38193, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.38}).addTo(map);circle.bindPopup('gid#38193: ' + '<a href="bio_pages/GN1_38193.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38193';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38210, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.28}).addTo(map);circle.bindPopup('gid#38210: ' + '<a href="bio_pages/GN1_38210.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38210';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38212, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:4.01}).addTo(map);circle.bindPopup('gid#38212: ' + '<a href="bio_pages/GN1_38212.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38212';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38216, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.5}).addTo(map);circle.bindPopup('gid#38216: ' + '<a href="bio_pages/GN1_38216.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38216';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38220, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.72}).addTo(map);circle.bindPopup('gid#38220: ' + '<a href="bio_pages/GN1_38220.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38220';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38225, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.59}).addTo(map);circle.bindPopup('gid#38225: ' + '<a href="bio_pages/GN1_38225.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38225';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38229, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:4.45}).addTo(map);circle.bindPopup('gid#38229: ' + '<a href="bio_pages/GN1_38229.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38229';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38235, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.65}).addTo(map);circle.bindPopup('gid#38235: ' + '<a href="bio_pages/GN1_38235.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38235';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38241, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:6.390000000000001}).addTo(map);circle.bindPopup('gid#38241: ' + '<a href="bio_pages/GN1_38241.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38241';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38244, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:1.5299999999999994}).addTo(map);circle.bindPopup('gid#38244: ' + '<a href="bio_pages/GN1_38244.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38244';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38247, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:4.41}).addTo(map);circle.bindPopup('gid#38247: ' + '<a href="bio_pages/GN1_38247.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38247';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38251, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:5.43}).addTo(map);circle.bindPopup('gid#38251: ' + '<a href="bio_pages/GN1_38251.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38251';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38255, {
# color: 'red',
# fillOpacity: 0,
# opacity: 5,
# radius:4.28}).addTo(map);circle.bindPopup('gid#38255: ' + '<a href="bio_pages/GN1_38255.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38255';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
