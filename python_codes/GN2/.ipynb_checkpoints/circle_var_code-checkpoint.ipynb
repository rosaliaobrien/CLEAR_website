# %%
import pandas as pd
import numpy as np
import csv

def cirsize(r):
    return 10-2*r

GN2data = pd.read_csv('/Users/rosaliaobrien/research/website/website_data/GN2.cat', sep=' ')
GN2data['radii'] = cirsize(GN2data['kr'])
print(GN2data)
# Out:
#        ids          ra        dec            x            y    kr  radii
# 0     8140  189.229000  62.182340  1654.888165    20.579623  4.07   1.86
# 1     8300  189.228632  62.183668  1665.192018   100.259651  3.76   2.48
# 2     8762  189.224540  62.185707  1779.753488   222.603333  3.50   3.00
# 3     9030  189.236969  62.186791  1431.794072   287.654834  3.50   3.00
# 4     9083  189.224191  62.187435  1789.517153   326.284039  4.14   1.72
# ..     ...         ...        ...          ...          ...   ...    ...
# 842  27309  189.215820  62.276158  2022.809532  5649.695205  3.82   2.36
# 843  27373  189.226143  62.276640  1734.666382  5678.581203  3.99   2.02
# 844  27475  189.219762  62.277070  1912.770472  5704.396808  3.94   2.12
# 845  27621  189.212116  62.277770  2126.173245  5746.438632  4.10   1.80
# 846  27686  189.220689  62.278337  1886.886938  5780.413471  3.66   2.68
#
# [847 rows x 7 columns]

# %%
def circle_var(gidn, radius, field):
    text1="var circle = L.circle(gid{0}, ".format(gidn)
    
    text2="{\n\
color: 'red',\n\
fillOpacity: 0,\n\
weight: 0.8,\n\
opacity: 3,\n"

    text3="radius:{0}".format(radius)
    
    text4="}).addTo(map);"
    
    text5="circle.bindPopup('gid#{0}: ' + '<a href=".format(gidn)
    
    text6='"bio_pages/{1}_{0}.html" target="_blank">'.format(gidn, field)
    
    text7="BIO PAGE</a>')\n\
circle.on('mouseover', function (e) {"
    
    text8="circlegid='{0}';\n\
document.getElementById('circle_tracker').innerHTML=circlegid".format(gidn)
    
    text9="});\n\
circle.on('mouseout', function (e) {\n\
circlegid='Move cursor over object';\n\
document.getElementById('circle_tracker').innerHTML=circlegid\n\
});"
    
    return text1 + text2 + text3 + text4 + text5 +text6 + text7 + text8 + text9

# %%
gid=GN2data['ids']
radii=GN2data['radii']


#for i, r in zip(gid, radii):
        #variables=circle_var(i,5,'GN')
       #print(variables)
        
for i,j in zip(gid, radii):
        variables=circle_var(i,j,'GN2')
        print(variables)
# Out:
# var circle = L.circle(gid8140, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.8599999999999994}).addTo(map);circle.bindPopup('gid#8140: ' + '<a href="bio_pages/GN2_8140.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='8140';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid8300, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.4800000000000004}).addTo(map);circle.bindPopup('gid#8300: ' + '<a href="bio_pages/GN2_8300.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='8300';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid8762, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#8762: ' + '<a href="bio_pages/GN2_8762.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='8762';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9030, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#9030: ' + '<a href="bio_pages/GN2_9030.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9030';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9083, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.7200000000000006}).addTo(map);circle.bindPopup('gid#9083: ' + '<a href="bio_pages/GN2_9083.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9083';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9128, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#9128: ' + '<a href="bio_pages/GN2_9128.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9128';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9178, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.1399999999999997}).addTo(map);circle.bindPopup('gid#9178: ' + '<a href="bio_pages/GN2_9178.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9178';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9211, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.26}).addTo(map);circle.bindPopup('gid#9211: ' + '<a href="bio_pages/GN2_9211.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9211';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9283, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#9283: ' + '<a href="bio_pages/GN2_9283.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9283';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9388, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.5999999999999996}).addTo(map);circle.bindPopup('gid#9388: ' + '<a href="bio_pages/GN2_9388.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9388';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9396, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#9396: ' + '<a href="bio_pages/GN2_9396.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9396';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9421, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#9421: ' + '<a href="bio_pages/GN2_9421.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9421';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9442, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#9442: ' + '<a href="bio_pages/GN2_9442.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9442';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9458, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#9458: ' + '<a href="bio_pages/GN2_9458.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9458';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9517, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.46}).addTo(map);circle.bindPopup('gid#9517: ' + '<a href="bio_pages/GN2_9517.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9517';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9569, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.9600000000000009}).addTo(map);circle.bindPopup('gid#9569: ' + '<a href="bio_pages/GN2_9569.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9569';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9594, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#9594: ' + '<a href="bio_pages/GN2_9594.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9594';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9670, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#9670: ' + '<a href="bio_pages/GN2_9670.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9670';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9706, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#9706: ' + '<a href="bio_pages/GN2_9706.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9706';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9717, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#9717: ' + '<a href="bio_pages/GN2_9717.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9717';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9748, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.76}).addTo(map);circle.bindPopup('gid#9748: ' + '<a href="bio_pages/GN2_9748.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9748';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9869, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:0.40000000000000036}).addTo(map);circle.bindPopup('gid#9869: ' + '<a href="bio_pages/GN2_9869.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9869';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9926, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:0.03999999999999915}).addTo(map);circle.bindPopup('gid#9926: ' + '<a href="bio_pages/GN2_9926.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9926';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid9948, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.3200000000000003}).addTo(map);circle.bindPopup('gid#9948: ' + '<a href="bio_pages/GN2_9948.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='9948';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10101, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.6999999999999993}).addTo(map);circle.bindPopup('gid#10101: ' + '<a href="bio_pages/GN2_10101.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10101';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10106, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.96}).addTo(map);circle.bindPopup('gid#10106: ' + '<a href="bio_pages/GN2_10106.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10106';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10153, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.5999999999999996}).addTo(map);circle.bindPopup('gid#10153: ' + '<a href="bio_pages/GN2_10153.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10153';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10172, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.8200000000000003}).addTo(map);circle.bindPopup('gid#10172: ' + '<a href="bio_pages/GN2_10172.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10172';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10202, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:0.6999999999999993}).addTo(map);circle.bindPopup('gid#10202: ' + '<a href="bio_pages/GN2_10202.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10202';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10205, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#10205: ' + '<a href="bio_pages/GN2_10205.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10205';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10209, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#10209: ' + '<a href="bio_pages/GN2_10209.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10209';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10219, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#10219: ' + '<a href="bio_pages/GN2_10219.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10219';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10284, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#10284: ' + '<a href="bio_pages/GN2_10284.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10284';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10304, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.5199999999999996}).addTo(map);circle.bindPopup('gid#10304: ' + '<a href="bio_pages/GN2_10304.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10304';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10336, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.7800000000000002}).addTo(map);circle.bindPopup('gid#10336: ' + '<a href="bio_pages/GN2_10336.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10336';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10375, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#10375: ' + '<a href="bio_pages/GN2_10375.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10375';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10389, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#10389: ' + '<a href="bio_pages/GN2_10389.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10389';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10393, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#10393: ' + '<a href="bio_pages/GN2_10393.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10393';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10470, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.62}).addTo(map);circle.bindPopup('gid#10470: ' + '<a href="bio_pages/GN2_10470.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10470';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10493, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#10493: ' + '<a href="bio_pages/GN2_10493.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10493';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10512, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#10512: ' + '<a href="bio_pages/GN2_10512.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10512';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10528, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.7}).addTo(map);circle.bindPopup('gid#10528: ' + '<a href="bio_pages/GN2_10528.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10528';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10566, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.5199999999999996}).addTo(map);circle.bindPopup('gid#10566: ' + '<a href="bio_pages/GN2_10566.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10566';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10619, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:0.7599999999999998}).addTo(map);circle.bindPopup('gid#10619: ' + '<a href="bio_pages/GN2_10619.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10619';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10639, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#10639: ' + '<a href="bio_pages/GN2_10639.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10639';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10653, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.6399999999999997}).addTo(map);circle.bindPopup('gid#10653: ' + '<a href="bio_pages/GN2_10653.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10653';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10657, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.0}).addTo(map);circle.bindPopup('gid#10657: ' + '<a href="bio_pages/GN2_10657.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10657';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10664, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#10664: ' + '<a href="bio_pages/GN2_10664.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10664';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10678, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.6399999999999997}).addTo(map);circle.bindPopup('gid#10678: ' + '<a href="bio_pages/GN2_10678.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10678';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10723, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#10723: ' + '<a href="bio_pages/GN2_10723.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10723';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10728, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.8600000000000003}).addTo(map);circle.bindPopup('gid#10728: ' + '<a href="bio_pages/GN2_10728.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10728';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10752, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.5999999999999996}).addTo(map);circle.bindPopup('gid#10752: ' + '<a href="bio_pages/GN2_10752.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10752';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10773, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.08}).addTo(map);circle.bindPopup('gid#10773: ' + '<a href="bio_pages/GN2_10773.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10773';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10886, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#10886: ' + '<a href="bio_pages/GN2_10886.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10886';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10921, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.42}).addTo(map);circle.bindPopup('gid#10921: ' + '<a href="bio_pages/GN2_10921.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10921';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid10926, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.2}).addTo(map);circle.bindPopup('gid#10926: ' + '<a href="bio_pages/GN2_10926.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='10926';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11011, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:-0.08000000000000007}).addTo(map);circle.bindPopup('gid#11011: ' + '<a href="bio_pages/GN2_11011.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11011';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11020, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.7599999999999998}).addTo(map);circle.bindPopup('gid#11020: ' + '<a href="bio_pages/GN2_11020.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11020';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11066, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.0599999999999996}).addTo(map);circle.bindPopup('gid#11066: ' + '<a href="bio_pages/GN2_11066.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11066';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11115, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#11115: ' + '<a href="bio_pages/GN2_11115.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11115';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11128, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.0599999999999996}).addTo(map);circle.bindPopup('gid#11128: ' + '<a href="bio_pages/GN2_11128.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11128';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11152, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#11152: ' + '<a href="bio_pages/GN2_11152.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11152';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11159, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.3800000000000008}).addTo(map);circle.bindPopup('gid#11159: ' + '<a href="bio_pages/GN2_11159.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11159';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11160, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.34}).addTo(map);circle.bindPopup('gid#11160: ' + '<a href="bio_pages/GN2_11160.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11160';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11201, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.6600000000000001}).addTo(map);circle.bindPopup('gid#11201: ' + '<a href="bio_pages/GN2_11201.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11201';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11228, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#11228: ' + '<a href="bio_pages/GN2_11228.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11228';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11288, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.3}).addTo(map);circle.bindPopup('gid#11288: ' + '<a href="bio_pages/GN2_11288.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11288';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11327, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#11327: ' + '<a href="bio_pages/GN2_11327.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11327';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11334, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:0.16000000000000014}).addTo(map);circle.bindPopup('gid#11334: ' + '<a href="bio_pages/GN2_11334.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11334';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11339, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#11339: ' + '<a href="bio_pages/GN2_11339.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11339';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11344, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.58}).addTo(map);circle.bindPopup('gid#11344: ' + '<a href="bio_pages/GN2_11344.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11344';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11346, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#11346: ' + '<a href="bio_pages/GN2_11346.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11346';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11381, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:0.08000000000000007}).addTo(map);circle.bindPopup('gid#11381: ' + '<a href="bio_pages/GN2_11381.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11381';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11393, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#11393: ' + '<a href="bio_pages/GN2_11393.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11393';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11429, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.7599999999999998}).addTo(map);circle.bindPopup('gid#11429: ' + '<a href="bio_pages/GN2_11429.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11429';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11431, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#11431: ' + '<a href="bio_pages/GN2_11431.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11431';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11443, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:0.35999999999999943}).addTo(map);circle.bindPopup('gid#11443: ' + '<a href="bio_pages/GN2_11443.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11443';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11487, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#11487: ' + '<a href="bio_pages/GN2_11487.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11487';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11502, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#11502: ' + '<a href="bio_pages/GN2_11502.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11502';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11514, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.84}).addTo(map);circle.bindPopup('gid#11514: ' + '<a href="bio_pages/GN2_11514.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11514';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11526, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.4800000000000004}).addTo(map);circle.bindPopup('gid#11526: ' + '<a href="bio_pages/GN2_11526.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11526';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11542, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.1799999999999997}).addTo(map);circle.bindPopup('gid#11542: ' + '<a href="bio_pages/GN2_11542.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11542';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11561, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#11561: ' + '<a href="bio_pages/GN2_11561.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11561';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11743, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.62}).addTo(map);circle.bindPopup('gid#11743: ' + '<a href="bio_pages/GN2_11743.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11743';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11768, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.7799999999999994}).addTo(map);circle.bindPopup('gid#11768: ' + '<a href="bio_pages/GN2_11768.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11768';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11784, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#11784: ' + '<a href="bio_pages/GN2_11784.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11784';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11785, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.5199999999999996}).addTo(map);circle.bindPopup('gid#11785: ' + '<a href="bio_pages/GN2_11785.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11785';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11800, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#11800: ' + '<a href="bio_pages/GN2_11800.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11800';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11802, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.1799999999999997}).addTo(map);circle.bindPopup('gid#11802: ' + '<a href="bio_pages/GN2_11802.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11802';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11814, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.0600000000000005}).addTo(map);circle.bindPopup('gid#11814: ' + '<a href="bio_pages/GN2_11814.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11814';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11849, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#11849: ' + '<a href="bio_pages/GN2_11849.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11849';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11941, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.9400000000000004}).addTo(map);circle.bindPopup('gid#11941: ' + '<a href="bio_pages/GN2_11941.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11941';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11946, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#11946: ' + '<a href="bio_pages/GN2_11946.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11946';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11964, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:0.9199999999999999}).addTo(map);circle.bindPopup('gid#11964: ' + '<a href="bio_pages/GN2_11964.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11964';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid11975, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.26}).addTo(map);circle.bindPopup('gid#11975: ' + '<a href="bio_pages/GN2_11975.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='11975';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid12006, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#12006: ' + '<a href="bio_pages/GN2_12006.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='12006';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid12025, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#12025: ' + '<a href="bio_pages/GN2_12025.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='12025';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid12088, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.0199999999999996}).addTo(map);circle.bindPopup('gid#12088: ' + '<a href="bio_pages/GN2_12088.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='12088';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid12129, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#12129: ' + '<a href="bio_pages/GN2_12129.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='12129';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid12131, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:0.6999999999999993}).addTo(map);circle.bindPopup('gid#12131: ' + '<a href="bio_pages/GN2_12131.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='12131';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid12154, {
# color: 'red',
# ...
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid25671, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.4800000000000004}).addTo(map);circle.bindPopup('gid#25671: ' + '<a href="bio_pages/GN2_25671.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='25671';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid25704, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.54}).addTo(map);circle.bindPopup('gid#25704: ' + '<a href="bio_pages/GN2_25704.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='25704';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid25765, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.6600000000000001}).addTo(map);circle.bindPopup('gid#25765: ' + '<a href="bio_pages/GN2_25765.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='25765';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid25773, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#25773: ' + '<a href="bio_pages/GN2_25773.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='25773';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid25845, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#25845: ' + '<a href="bio_pages/GN2_25845.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='25845';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid25889, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.26}).addTo(map);circle.bindPopup('gid#25889: ' + '<a href="bio_pages/GN2_25889.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='25889';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid25926, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.7}).addTo(map);circle.bindPopup('gid#25926: ' + '<a href="bio_pages/GN2_25926.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='25926';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26172, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#26172: ' + '<a href="bio_pages/GN2_26172.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26172';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26179, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#26179: ' + '<a href="bio_pages/GN2_26179.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26179';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26193, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#26193: ' + '<a href="bio_pages/GN2_26193.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26193';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26235, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.7400000000000002}).addTo(map);circle.bindPopup('gid#26235: ' + '<a href="bio_pages/GN2_26235.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26235';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26358, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.1999999999999993}).addTo(map);circle.bindPopup('gid#26358: ' + '<a href="bio_pages/GN2_26358.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26358';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26373, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#26373: ' + '<a href="bio_pages/GN2_26373.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26373';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26410, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.7800000000000002}).addTo(map);circle.bindPopup('gid#26410: ' + '<a href="bio_pages/GN2_26410.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26410';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26458, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.9800000000000004}).addTo(map);circle.bindPopup('gid#26458: ' + '<a href="bio_pages/GN2_26458.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26458';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26518, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.0199999999999996}).addTo(map);circle.bindPopup('gid#26518: ' + '<a href="bio_pages/GN2_26518.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26518';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26607, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.8599999999999994}).addTo(map);circle.bindPopup('gid#26607: ' + '<a href="bio_pages/GN2_26607.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26607';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26613, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#26613: ' + '<a href="bio_pages/GN2_26613.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26613';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26629, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.7199999999999998}).addTo(map);circle.bindPopup('gid#26629: ' + '<a href="bio_pages/GN2_26629.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26629';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26806, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.7}).addTo(map);circle.bindPopup('gid#26806: ' + '<a href="bio_pages/GN2_26806.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26806';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26809, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#26809: ' + '<a href="bio_pages/GN2_26809.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26809';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26822, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.92}).addTo(map);circle.bindPopup('gid#26822: ' + '<a href="bio_pages/GN2_26822.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26822';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26858, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#26858: ' + '<a href="bio_pages/GN2_26858.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26858';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26882, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.5}).addTo(map);circle.bindPopup('gid#26882: ' + '<a href="bio_pages/GN2_26882.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26882';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26903, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:0.33999999999999986}).addTo(map);circle.bindPopup('gid#26903: ' + '<a href="bio_pages/GN2_26903.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26903';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27008, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#27008: ' + '<a href="bio_pages/GN2_27008.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27008';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27204, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0}).addTo(map);circle.bindPopup('gid#27204: ' + '<a href="bio_pages/GN2_27204.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27204';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27305, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.76}).addTo(map);circle.bindPopup('gid#27305: ' + '<a href="bio_pages/GN2_27305.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27305';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27309, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.3600000000000003}).addTo(map);circle.bindPopup('gid#27309: ' + '<a href="bio_pages/GN2_27309.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27309';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27373, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.0199999999999996}).addTo(map);circle.bindPopup('gid#27373: ' + '<a href="bio_pages/GN2_27373.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27373';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27475, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.12}).addTo(map);circle.bindPopup('gid#27475: ' + '<a href="bio_pages/GN2_27475.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27475';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27621, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.8000000000000007}).addTo(map);circle.bindPopup('gid#27621: ' + '<a href="bio_pages/GN2_27621.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27621';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27686, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.6799999999999997}).addTo(map);circle.bindPopup('gid#27686: ' + '<a href="bio_pages/GN2_27686.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27686';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
