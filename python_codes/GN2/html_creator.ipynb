# %%
import numpy as np
import csv
import pandas as pd

# %%
def circle_pos(x_pos ,y_pos ,gidn):
    text='var gid{0} = xy({1}/sc, {2}/sc)'.format(gidn, x_pos, y_pos)
    return text

def cirsize(r):
    return 10-r

# %%
GN2data = pd.read_csv('/Users/rosaliaobrien/research/website_data/GN2.cat', sep=' ')
GN2data['radii'] = cirsize(GN2data['kr'])

# %%
def html_gen(field, scale_size, x_len, y_len, xpos, ypos, gidn, radius, ra0, dec0, dra, ddec):

    text00='<html>\n\
<head>\n\
<title>{0}</title>\n\
<meta name="viewport" content="width=device-width, initial-scale=1">\n\
<link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">\n\
<link rel="stylesheet" href="https://unpkg.com/leaflet@1.3.1/dist/leaflet.css"\n\
   integrity="sha512-Rksm5RenBEKSKFjgI3a41vrjkw4EVPlJ3+OiI65vTjIdo9brlAacEuKOiQ5OFh7cOI1bkDwLqdLw3Zg0cRJAAQ=="\n\
   crossorigin=""/>\n\
<script src="https://unpkg.com/leaflet@1.3.1/dist/leaflet.js"\n\
   integrity="sha512-/Nsx9X4HebavoBvEBuyp3I7od5tA0UzAxs+j83KgC8PU0kgB4XiK4Lfe4y4cgBtaRJQEIFCW+oC506aPT2L1zw=="\n\
   crossorigin=""></script>\n\
<style type="text/css">\n\
    /* edit map */'.format(field)
    
    text01='#map {\n\
    float: right;\n\
    width: 1000px;\n\
    height: 1000px;\n\
    border: 3px solid #d9d9d9;\n\
    padding: 10px;\n\
}\n\
#positions {\n\
    float: left;\n\
    position: sticky;\n\
}\n\
body {\n\
    font-family: Arial;\n\
}\n\
* {\n\
    box-sizing: border-box;\n\
}\n\
.navbar {\n\
    overflow: hidden;\n\
    background-color: #333;\n\
    font-family: Arial, Helvetica, sans-serif;\n\
}\n\
.navbar a {\n\
    float: left;\n\
    font-size: 16px;\n\
    color: white;\n\
    text-align: center;\n\
    padding: 14px 16px;\n\
    text-decoration: none;\n\
}\n\
.dropdown {\n\
    float: left;\n\
    overflow: hidden;\n\
}\n\
.dropdown .dropbtn {\n\
    font-size: 16px;    \n\
    border: none;\n\
    outline: none;\n\
    color: white;\n\
    padding: 14px 16px;\n\
    background-color: inherit;\n\
    font-family: inherit;\n\
    margin: 0;\n\
}\n\
.navbar a:hover, .dropdown:hover .dropbtn {\n\\n\
    background-color: red;\n\
}\n\
.dropdown-content {\n\
    display: none;\n\
    position: absolute;\n\
    background-color: #f9f9f9;\n\
    min-width: 160px;\n\
    box-shadow: 0px 8px 16px 0px rgba(0,0,0,0.2);\n\
    z-index: 100000;\n\
}\n\
.dropdown-content a {\n\
    float: none;\n\
    color: black;\n\
    padding: 12px 16px;\n\
    text-decoration: none;\n\
    display: block;\n\
    text-align: left;\n\
}\n\
.dropdown-content a:hover {\n\
    background-color: #ddd;\n\
}\n\
.dropdown:hover .dropdown-content {\n\
    display: block;\n\
}\n\
.resetbutton {\n\
  background-color: #333;\n\
  border: none;\n\
  color: white;\n\
  padding: 7px 14px;\n\
  text-align: center;\n\
  text-decoration: none;\n\
  display: inline-block;\n\
  font-size: 16px;\n\
  margin: 4px 2px;\n\
  cursor: pointer;\n\
}\n\
</style>\n\
</head>\n\
<body>\n\
<div class="navbar">\n\
  <a href="/Users/rosaliaobrien/research/html_codes/home_page_map.html">Home</a>\n\
  <div class="dropdown">\n\
    <button class="dropbtn" onclick=window.open("/Users/rosaliaobrien/research/html_codes/GN_main.html","_self")>GOODS North\n\
      <i class="fa fa-caret-down"></i>\n\
    </button>\n\\n\
    <div class="dropdown-content">\n\
      <a href="/Users/rosaliaobrien/research/html_codes/GN1.html">GN1</a>\n\
      <a href="/Users/rosaliaobrien/research/html_codes/GN2.html">GN2</a>\n\
      <a href="/Users/rosaliaobrien/research/html_codes/GN3.html">GN3</a>\n\
      <a href="/Users/rosaliaobrien/research/html_codes/GN4.html">GN4</a>\n\
      <a href="/Users/rosaliaobrien/research/html_codes/GN5.html">GN5</a>\n\
      <a href="/Users/rosaliaobrien/research/html_codes/GN7.html">GN7</a>\n\
    </div>\n\
  </div> \n\
  <div class="dropdown">\n\
    <button class="dropbtn" onclick=window.open("/Users/rosaliaobrien/research/html_codes/GS_main.html","_self")>GOODS South\n\
      <i class="fa fa-caret-down"></i>\n\
    </button>\n\
    <div class="dropdown-content">\n\
      <a href="/Users/rosaliaobrien/research/html_codes/ERSPRIME.html">ERSPRIME</a>\n\
      <a href="/Users/rosaliaobrien/research/html_codes/GS1.html">GS1</a>\n\
      <a href="/Users/rosaliaobrien/research/html_codes/GS2.html">GS2</a>\n\
      <a href="/Users/rosaliaobrien/research/html_codes/GS3.html">GS3</a>\n\
      <a href="/Users/rosaliaobrien/research/html_codes/GS4.html">GS4</a>\n\
      <a href="/Users/rosaliaobrien/research/html_codes/GS5.html">GS5</a>\n\
    </div>\n\
  </div> \n\
</div>'

text02='<h1> {0} </h1>\n\

	<div id="map"></div>\n\
	<script type="text/javascript">\n\
	// initialize the map on the "map" div\n\
	var map = L.map('map', {\n\
		// L.CRS.Simple is a simple CRS (coordinate reference system) that maps longitude and latitude into x and y directly (square grid)\n\
		crs: L.CRS.Simple,\n\
		maxZoom: 2,\n\

	});\n\
    sc = {1}\n\
	var bounds = [[0,0],[{2}/sc, {3}/sc]];\n\
	var image = L.imageOverlay("/Users/rosaliaobrien/research/website_data/GN2_img.pdf", bounds).addTo(map);\n\

	map.fitBounds(bounds);'.format(field, scale_size, y_len, x_len)

    text03='function onMouseMove(e) {\n\
                                        x=(e.latlng.lng)*sc;\n\
                                        y=(e.latlng.lat)*sc;\n\
                                        y=Math.round(y);\n\
                                        x=Math.round(x);\n\
                                        r=(e.latlng.lng)*sc*{0}+{1}-0.0059-0.00005+0.007139;\n\
                                        d=(e.latlng.lat)*sc*{2}+{3}+0.0031-0.03701;\n\
                                        r=Math.round(r*100000)/100000;\n\
                                        d=Math.round(d*100000)/100000;\n\
                                        trackxy="<big> x, y: "+x+", "+y+"</big>";\n\
                                        trackRD="<big> RA, DEC: "+r+", "+d+"</big>";\n\
                                        document.getElementById("tracker").innerHTML=trackxy;\n\
                                        document.getElementById("tracker2").innerHTML=trackRD;}\n\
                                        map.on("mousemove", onMouseMove);'.format(ra0, dra, dec0, ddec )
   

text04='var yx = L.latLng;\n\

var xy = function(x, y) {\n\
	if (L.Util.isArray(x)) {\n\
		return yx(x[1], x[0]);\n\
	}\n\
	return yx(y, x);\n\
};'

    text0='var gid{0} = xy({1}/sc, {2}/sc)'.format(gidn, x_pos, y_pos)
    return text

    text1="var circle = L.circle(gid{0}, ".format(gidn)
    
    text2="{\n\
color: 'red',\n\
fillOpacity: 0,\n\
opacity: 10,\n"

    text3="radius:{0}".format(radius)
    
    text4="}).addTo(map);"
    
    text5="circle.bindPopup('gid#{0}: ' + '<a href=".format(gidn)
    
    text6='"bio_pages/{1}_{0}.html" target="_blank">'.format(gidn, field)
    
    text7="BIO PAGE</a>')\n\
circle.on('mouseover', function (e) {"
    
    text8="circlegid='{0}';\n\
document.getElementById('circle_tracker').innerHTML=circlegid".format(gidn)
    
    text9="});\n\
circle.on('mouseout', function (e) {\n\
circlegid='Move cursor over object';\n\
document.getElementById('circle_tracker').innerHTML=circlegid\n\
});"
    
    return text00 + text01 + text02 + text03 + text04 + text0 + text1 + text2 + text3 + text4 + text5 +text6 + text7 + text8 + text9
# Out:
#   File "<tokenize>", line 124
# ...

# %%
gid = GN2data['ids']
xpos = GN2data['x']
ypos = GN2data['y']
radii = GN2data['radii']

for i, x, y in zip(gid, xpos, ypos):
        positions=circle_pos(x,np.abs(y - 6025),i)
        print(positions)
        
for i,j in zip(gid, radii):
        variables=circle_var(i,j,'GN2')
        print(variables)
        
for i, j, k, l in zip(gid, xpos, ypos, radii):
        htmlpage=html_gen(GN2, 3.5, 4395, 6025, xpos, ypos, gidn, radii, 189.59649618807867, 62.06742527515218, -0.000035782, 0.00001666)
        np.savetxt('/Users/rosaliaobrien/research/html_codes/practiceGN2page.html',htmlpage,fmt='%s')
