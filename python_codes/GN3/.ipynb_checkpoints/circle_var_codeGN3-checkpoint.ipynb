# %%
import pandas as pd
import numpy as np
import csv

def cirsize(r):
    return 8-r

GN3data = pd.read_csv('/Users/rosaliaobrien/research/website_data/GN3.cat', sep=' ')
GN3data['radii'] = cirsize(GN3data['kr'])
#print(GN3data)

# %%
def circle_var(gidn, radius, field):
    text1="var circle = L.circle(gid{0}, ".format(gidn)
    
    text2="{\n\
color: 'red',\n\
fillOpacity: 0,\n\
opacity: 10,\n"

    text3="radius:{0}".format(radius)
    
    text4="}).addTo(map);"
    
    text5="circle.bindPopup('gid#{0}: ' + '<a href=".format(gidn)
    
    text6='"bio_pages/{1}_{0}.html" target="_blank">'.format(gidn, field)
    
    text7="BIO PAGE</a>')\n\
circle.on('mouseover', function (e) {"
    
    text8="circlegid='{0}';\n\
document.getElementById('circle_tracker').innerHTML=circlegid".format(gidn)
    
    text9="});\n\
circle.on('mouseout', function (e) {\n\
circlegid='Move cursor over object';\n\
document.getElementById('circle_tracker').innerHTML=circlegid\n\
});"
    
    return text1 + text2 + text3 + text4 + text5 +text6 + text7 + text8 + text9

# %%
gid=GN3data['ids']
radii=GN3data['radii']
        
for i,j in zip(gid, radii):
        variables=circle_var(i,j,'GN3')
        print(variables)
# Out:
# var circle = L.circle(gid24766, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:2.75}).addTo(map);circle.bindPopup('gid#24766: ' + '<a href="bio_pages/GN3_24766.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='24766';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid24798, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.74}).addTo(map);circle.bindPopup('gid#24798: ' + '<a href="bio_pages/GN3_24798.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='24798';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid24978, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#24978: ' + '<a href="bio_pages/GN3_24978.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='24978';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid25045, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.9000000000000004}).addTo(map);circle.bindPopup('gid#25045: ' + '<a href="bio_pages/GN3_25045.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='25045';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid25329, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.0600000000000005}).addTo(map);circle.bindPopup('gid#25329: ' + '<a href="bio_pages/GN3_25329.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='25329';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid25387, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#25387: ' + '<a href="bio_pages/GN3_25387.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='25387';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid25549, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.42}).addTo(map);circle.bindPopup('gid#25549: ' + '<a href="bio_pages/GN3_25549.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='25549';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid25550, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.17}).addTo(map);circle.bindPopup('gid#25550: ' + '<a href="bio_pages/GN3_25550.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='25550';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid25721, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#25721: ' + '<a href="bio_pages/GN3_25721.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='25721';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid25737, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.48}).addTo(map);circle.bindPopup('gid#25737: ' + '<a href="bio_pages/GN3_25737.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='25737';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid25797, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.07}).addTo(map);circle.bindPopup('gid#25797: ' + '<a href="bio_pages/GN3_25797.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='25797';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid25947, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#25947: ' + '<a href="bio_pages/GN3_25947.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='25947';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26095, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.4399999999999995}).addTo(map);circle.bindPopup('gid#26095: ' + '<a href="bio_pages/GN3_26095.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26095';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26193, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#26193: ' + '<a href="bio_pages/GN3_26193.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26193';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26197, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#26197: ' + '<a href="bio_pages/GN3_26197.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26197';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26257, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#26257: ' + '<a href="bio_pages/GN3_26257.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26257';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26457, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.42}).addTo(map);circle.bindPopup('gid#26457: ' + '<a href="bio_pages/GN3_26457.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26457';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26537, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.7300000000000004}).addTo(map);circle.bindPopup('gid#26537: ' + '<a href="bio_pages/GN3_26537.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26537';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26542, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#26542: ' + '<a href="bio_pages/GN3_26542.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26542';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26645, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#26645: ' + '<a href="bio_pages/GN3_26645.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26645';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26652, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#26652: ' + '<a href="bio_pages/GN3_26652.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26652';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26673, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#26673: ' + '<a href="bio_pages/GN3_26673.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26673';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26747, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#26747: ' + '<a href="bio_pages/GN3_26747.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26747';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26767, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.390000000000001}).addTo(map);circle.bindPopup('gid#26767: ' + '<a href="bio_pages/GN3_26767.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26767';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26778, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#26778: ' + '<a href="bio_pages/GN3_26778.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26778';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26788, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#26788: ' + '<a href="bio_pages/GN3_26788.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26788';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26789, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.92}).addTo(map);circle.bindPopup('gid#26789: ' + '<a href="bio_pages/GN3_26789.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26789';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26823, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#26823: ' + '<a href="bio_pages/GN3_26823.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26823';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26842, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.87}).addTo(map);circle.bindPopup('gid#26842: ' + '<a href="bio_pages/GN3_26842.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26842';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26859, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#26859: ' + '<a href="bio_pages/GN3_26859.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26859';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26873, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.18}).addTo(map);circle.bindPopup('gid#26873: ' + '<a href="bio_pages/GN3_26873.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26873';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26879, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.76}).addTo(map);circle.bindPopup('gid#26879: ' + '<a href="bio_pages/GN3_26879.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26879';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26910, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.4}).addTo(map);circle.bindPopup('gid#26910: ' + '<a href="bio_pages/GN3_26910.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26910';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26922, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.42}).addTo(map);circle.bindPopup('gid#26922: ' + '<a href="bio_pages/GN3_26922.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26922';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid26946, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.83}).addTo(map);circle.bindPopup('gid#26946: ' + '<a href="bio_pages/GN3_26946.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='26946';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27006, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27006: ' + '<a href="bio_pages/GN3_27006.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27006';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27018, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.76}).addTo(map);circle.bindPopup('gid#27018: ' + '<a href="bio_pages/GN3_27018.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27018';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27051, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.24}).addTo(map);circle.bindPopup('gid#27051: ' + '<a href="bio_pages/GN3_27051.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27051';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27057, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27057: ' + '<a href="bio_pages/GN3_27057.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27057';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27060, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.6100000000000003}).addTo(map);circle.bindPopup('gid#27060: ' + '<a href="bio_pages/GN3_27060.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27060';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27073, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27073: ' + '<a href="bio_pages/GN3_27073.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27073';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27101, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27101: ' + '<a href="bio_pages/GN3_27101.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27101';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27136, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.2}).addTo(map);circle.bindPopup('gid#27136: ' + '<a href="bio_pages/GN3_27136.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27136';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27145, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.4400000000000004}).addTo(map);circle.bindPopup('gid#27145: ' + '<a href="bio_pages/GN3_27145.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27145';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27179, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.34}).addTo(map);circle.bindPopup('gid#27179: ' + '<a href="bio_pages/GN3_27179.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27179';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27185, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27185: ' + '<a href="bio_pages/GN3_27185.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27185';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27234, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.109999999999999}).addTo(map);circle.bindPopup('gid#27234: ' + '<a href="bio_pages/GN3_27234.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27234';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27235, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27235: ' + '<a href="bio_pages/GN3_27235.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27235';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27240, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.42}).addTo(map);circle.bindPopup('gid#27240: ' + '<a href="bio_pages/GN3_27240.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27240';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27269, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27269: ' + '<a href="bio_pages/GN3_27269.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27269';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27308, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.470000000000001}).addTo(map);circle.bindPopup('gid#27308: ' + '<a href="bio_pages/GN3_27308.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27308';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27404, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.48}).addTo(map);circle.bindPopup('gid#27404: ' + '<a href="bio_pages/GN3_27404.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27404';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27422, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27422: ' + '<a href="bio_pages/GN3_27422.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27422';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27440, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27440: ' + '<a href="bio_pages/GN3_27440.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27440';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27472, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27472: ' + '<a href="bio_pages/GN3_27472.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27472';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27519, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.359999999999999}).addTo(map);circle.bindPopup('gid#27519: ' + '<a href="bio_pages/GN3_27519.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27519';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27532, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27532: ' + '<a href="bio_pages/GN3_27532.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27532';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27572, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27572: ' + '<a href="bio_pages/GN3_27572.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27572';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27660, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27660: ' + '<a href="bio_pages/GN3_27660.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27660';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27668, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:1.7800000000000002}).addTo(map);circle.bindPopup('gid#27668: ' + '<a href="bio_pages/GN3_27668.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27668';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27676, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27676: ' + '<a href="bio_pages/GN3_27676.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27676';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27689, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.32}).addTo(map);circle.bindPopup('gid#27689: ' + '<a href="bio_pages/GN3_27689.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27689';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27698, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27698: ' + '<a href="bio_pages/GN3_27698.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27698';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27722, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.29}).addTo(map);circle.bindPopup('gid#27722: ' + '<a href="bio_pages/GN3_27722.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27722';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27739, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:2.99}).addTo(map);circle.bindPopup('gid#27739: ' + '<a href="bio_pages/GN3_27739.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27739';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27778, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:2.9000000000000004}).addTo(map);circle.bindPopup('gid#27778: ' + '<a href="bio_pages/GN3_27778.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27778';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27825, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.42}).addTo(map);circle.bindPopup('gid#27825: ' + '<a href="bio_pages/GN3_27825.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27825';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27829, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.46}).addTo(map);circle.bindPopup('gid#27829: ' + '<a href="bio_pages/GN3_27829.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27829';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27830, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27830: ' + '<a href="bio_pages/GN3_27830.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27830';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27837, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.13}).addTo(map);circle.bindPopup('gid#27837: ' + '<a href="bio_pages/GN3_27837.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27837';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27877, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:2.8499999999999996}).addTo(map);circle.bindPopup('gid#27877: ' + '<a href="bio_pages/GN3_27877.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27877';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27901, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27901: ' + '<a href="bio_pages/GN3_27901.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27901';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27916, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.6799999999999997}).addTo(map);circle.bindPopup('gid#27916: ' + '<a href="bio_pages/GN3_27916.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27916';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27930, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.3}).addTo(map);circle.bindPopup('gid#27930: ' + '<a href="bio_pages/GN3_27930.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27930';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27933, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.49}).addTo(map);circle.bindPopup('gid#27933: ' + '<a href="bio_pages/GN3_27933.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27933';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27951, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27951: ' + '<a href="bio_pages/GN3_27951.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27951';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27978, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#27978: ' + '<a href="bio_pages/GN3_27978.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27978';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid27995, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.04}).addTo(map);circle.bindPopup('gid#27995: ' + '<a href="bio_pages/GN3_27995.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='27995';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28005, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#28005: ' + '<a href="bio_pages/GN3_28005.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28005';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28015, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#28015: ' + '<a href="bio_pages/GN3_28015.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28015';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28040, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.140000000000001}).addTo(map);circle.bindPopup('gid#28040: ' + '<a href="bio_pages/GN3_28040.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28040';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28055, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.76}).addTo(map);circle.bindPopup('gid#28055: ' + '<a href="bio_pages/GN3_28055.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28055';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28073, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#28073: ' + '<a href="bio_pages/GN3_28073.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28073';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28082, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#28082: ' + '<a href="bio_pages/GN3_28082.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28082';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28121, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#28121: ' + '<a href="bio_pages/GN3_28121.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28121';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28194, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.9800000000000004}).addTo(map);circle.bindPopup('gid#28194: ' + '<a href="bio_pages/GN3_28194.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28194';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28206, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.48}).addTo(map);circle.bindPopup('gid#28206: ' + '<a href="bio_pages/GN3_28206.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28206';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28215, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.24}).addTo(map);circle.bindPopup('gid#28215: ' + '<a href="bio_pages/GN3_28215.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28215';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28237, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.4299999999999997}).addTo(map);circle.bindPopup('gid#28237: ' + '<a href="bio_pages/GN3_28237.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28237';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28243, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#28243: ' + '<a href="bio_pages/GN3_28243.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28243';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28284, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#28284: ' + '<a href="bio_pages/GN3_28284.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28284';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28308, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.37}).addTo(map);circle.bindPopup('gid#28308: ' + '<a href="bio_pages/GN3_28308.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28308';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28379, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#28379: ' + '<a href="bio_pages/GN3_28379.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28379';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28381, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#28381: ' + '<a href="bio_pages/GN3_28381.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28381';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28393, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.34}).addTo(map);circle.bindPopup('gid#28393: ' + '<a href="bio_pages/GN3_28393.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28393';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28395, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#28395: ' + '<a href="bio_pages/GN3_28395.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28395';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28406, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.45}).addTo(map);circle.bindPopup('gid#28406: ' + '<a href="bio_pages/GN3_28406.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28406';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28436, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.46}).addTo(map);circle.bindPopup('gid#28436: ' + '<a href="bio_pages/GN3_28436.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28436';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28440, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#28440: ' + '<a href="bio_pages/GN3_28440.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28440';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28451, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#28451: ' + '<a href="bio_pages/GN3_28451.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28451';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28466, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.51}).addTo(map);circle.bindPopup('gid#28466: ' + '<a href="bio_pages/GN3_28466.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28466';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28496, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.470000000000001}).addTo(map);circle.bindPopup('gid#28496: ' + '<a href="bio_pages/GN3_28496.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28496';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28519, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.42}).addTo(map);circle.bindPopup('gid#28519: ' + '<a href="bio_pages/GN3_28519.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='28519';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid28535, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# ...
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37133, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37133: ' + '<a href="bio_pages/GN3_37133.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37133';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37166, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.46}).addTo(map);circle.bindPopup('gid#37166: ' + '<a href="bio_pages/GN3_37166.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37166';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37171, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.17}).addTo(map);circle.bindPopup('gid#37171: ' + '<a href="bio_pages/GN3_37171.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37171';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37180, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37180: ' + '<a href="bio_pages/GN3_37180.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37180';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37186, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37186: ' + '<a href="bio_pages/GN3_37186.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37186';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37188, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.109999999999999}).addTo(map);circle.bindPopup('gid#37188: ' + '<a href="bio_pages/GN3_37188.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37188';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37197, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.43}).addTo(map);circle.bindPopup('gid#37197: ' + '<a href="bio_pages/GN3_37197.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37197';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37210, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37210: ' + '<a href="bio_pages/GN3_37210.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37210';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37216, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.35}).addTo(map);circle.bindPopup('gid#37216: ' + '<a href="bio_pages/GN3_37216.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37216';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37230, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.4299999999999997}).addTo(map);circle.bindPopup('gid#37230: ' + '<a href="bio_pages/GN3_37230.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37230';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37232, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37232: ' + '<a href="bio_pages/GN3_37232.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37232';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37244, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.34}).addTo(map);circle.bindPopup('gid#37244: ' + '<a href="bio_pages/GN3_37244.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37244';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37257, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.13}).addTo(map);circle.bindPopup('gid#37257: ' + '<a href="bio_pages/GN3_37257.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37257';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37265, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37265: ' + '<a href="bio_pages/GN3_37265.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37265';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37281, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.24}).addTo(map);circle.bindPopup('gid#37281: ' + '<a href="bio_pages/GN3_37281.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37281';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37286, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.37}).addTo(map);circle.bindPopup('gid#37286: ' + '<a href="bio_pages/GN3_37286.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37286';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37308, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:2.5300000000000002}).addTo(map);circle.bindPopup('gid#37308: ' + '<a href="bio_pages/GN3_37308.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37308';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37311, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37311: ' + '<a href="bio_pages/GN3_37311.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37311';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37321, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:2.01}).addTo(map);circle.bindPopup('gid#37321: ' + '<a href="bio_pages/GN3_37321.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37321';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37325, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.37}).addTo(map);circle.bindPopup('gid#37325: ' + '<a href="bio_pages/GN3_37325.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37325';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37326, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.1}).addTo(map);circle.bindPopup('gid#37326: ' + '<a href="bio_pages/GN3_37326.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37326';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37327, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.6500000000000004}).addTo(map);circle.bindPopup('gid#37327: ' + '<a href="bio_pages/GN3_37327.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37327';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37333, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.140000000000001}).addTo(map);circle.bindPopup('gid#37333: ' + '<a href="bio_pages/GN3_37333.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37333';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37334, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.34}).addTo(map);circle.bindPopup('gid#37334: ' + '<a href="bio_pages/GN3_37334.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37334';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37343, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37343: ' + '<a href="bio_pages/GN3_37343.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37343';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37371, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:3.4299999999999997}).addTo(map);circle.bindPopup('gid#37371: ' + '<a href="bio_pages/GN3_37371.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37371';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37392, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.45}).addTo(map);circle.bindPopup('gid#37392: ' + '<a href="bio_pages/GN3_37392.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37392';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37411, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:0.8300000000000001}).addTo(map);circle.bindPopup('gid#37411: ' + '<a href="bio_pages/GN3_37411.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37411';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37413, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.08}).addTo(map);circle.bindPopup('gid#37413: ' + '<a href="bio_pages/GN3_37413.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37413';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37432, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37432: ' + '<a href="bio_pages/GN3_37432.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37432';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37435, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37435: ' + '<a href="bio_pages/GN3_37435.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37435';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37472, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:1.8899999999999997}).addTo(map);circle.bindPopup('gid#37472: ' + '<a href="bio_pages/GN3_37472.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37472';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37486, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37486: ' + '<a href="bio_pages/GN3_37486.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37486';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37602, {
# color: 'red',
# fillOpacity: 0,
# opacity: 10,
# radius:4.32}).addTo(map);circle.bindPopup('gid#37602: ' + '<a href="bio_pages/GN3_37602.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37602';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
