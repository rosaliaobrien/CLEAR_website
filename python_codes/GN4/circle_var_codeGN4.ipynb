# %%
import pandas as pd
import numpy as np
import csv

def cirsize(r):
    return 7-r

GN4data = pd.read_csv('/Users/rosaliaobrien/research/website_data/GN4.cat', sep=' ')
GN4data['radii'] = cirsize(GN4data['kr'])
print(GN4data)
# Out:
#        ids          ra        dec            x            y    kr  radii
# 0    14810  189.265932  62.214706  3233.927336    20.840814  3.50   3.50
# 1    14883  189.275009  62.216029  2980.104427   100.384852  3.50   3.50
# 2    15255  189.273848  62.217589  3012.641053   193.961863  3.50   3.50
# 3    15516  189.278266  62.218502  2889.125304   248.832350  3.50   3.50
# 4    15861  189.259978  62.220442  3400.624828   364.912476  4.09   2.91
# 5    15901  189.286531  62.220285  2658.081584   356.004249  3.60   3.40
# 6    15957  189.276751  62.220580  2931.586550   373.480330  3.50   3.50
# 7    15998  189.274269  62.221444  3001.030056   425.270061  3.50   3.50
# 8    15999  189.261692  62.220707  3352.702216   380.836315  3.64   3.36
# 9    16083  189.259257  62.221225  3420.809284   411.882817  3.50   3.50
# 10   16229  189.258456  62.223067  3443.258997   522.392337  3.50   3.50
# 11   16230  189.293259  62.222145  2470.048535   467.782215  3.50   3.50
# 12   16286  189.284822  62.222411  2705.983459   483.522095  3.50   3.50
# 13   16315  189.269468  62.222477  3135.321080   487.160389  3.71   3.29
# 14   16343  189.277096  62.222917  2922.043905   513.707482  3.54   3.46
# 15   16469  189.273325  62.223426  3027.509540   544.171612  3.59   3.41
# 16   16603  189.305260  62.224288  2134.620714   596.728184  3.64   3.36
# 17   16616  189.298958  62.224787  2310.861471   626.468202  5.10   1.90
# 18   16628  189.299984  62.223814  2282.109939   568.119622  4.50   2.50
# 19   16635  189.292537  62.224407  2490.371558   603.482111  3.78   3.22
# 20   16674  189.278279  62.224515  2889.038440   609.612512  3.63   3.37
# 21   16755  189.274517  62.224818  2994.238648   627.714901  3.87   3.13
# 22   16797  189.272429  62.224641  3052.612357   617.054468  4.35   2.65
# 23   16827  189.297354  62.225300  2355.742343   657.200027  3.65   3.35
# 24   16883  189.275865  62.225779  2956.590372   685.401986  3.50   3.50
# 25   16903  189.296868  62.225249  2369.327555   654.125657  3.50   3.50
# 26   16942  189.304621  62.226049  2152.611611   702.367059  3.50   3.50
# 27   16945  189.257693  62.225151  3464.650010   647.422608  3.50   3.50
# 28   16987  189.307773  62.226441  2064.513432   725.992616  3.50   3.50
# 29   17029  189.272862  62.226293  3040.573246   716.182667  3.68   3.32
# ..     ...         ...        ...          ...          ...   ...    ...
# 843  32018  189.284643  62.302516  2715.147251  5289.817114  4.32   2.68
# 844  32103  189.259172  62.305295  3425.566238  5456.082120  4.07   2.93
# 845  32108  189.277164  62.305097  2923.839182  5444.508735  3.50   3.50
# 846  32113  189.248609  62.304070  3720.099411  5382.467013  3.50   3.50
# 847  32149  189.258929  62.304447  3432.318629  5405.198880  3.74   3.26
# 848  32229  189.264261  62.304327  3283.624324  5398.074641  3.50   3.50
# 849  32250  189.234281  62.303975  4119.660431  5376.687822  4.81   2.19
# 850  32309  189.274177  62.304811  3007.122013  5427.288155  3.53   3.47
# 851  32329  189.250974  62.304404  3654.154140  5402.528611  3.52   3.48
# 852  32340  189.260320  62.305648  3393.563910  5477.277541  3.50   3.50
# 853  32418  189.255221  62.306407  3535.769754  5522.753541  3.50   3.50
# 854  32545  189.233385  62.305860  4144.655370  5489.785939  3.58   3.42
# 855  32606  189.268020  62.306142  3178.865154  5507.035531  3.77   3.23
# 856  32637  189.254689  62.306336  3550.602643  5518.487499  4.14   2.86
# 857  32649  189.249976  62.306779  3682.031817  5545.019373  3.57   3.43
# 858  32719  189.269131  62.307222  3147.925640  5571.854729  3.50   3.50
# 859  32843  189.261652  62.308781  3356.516589  5665.276333  3.50   3.50
# 860  32867  189.250672  62.307998  3662.649287  5618.165970  4.14   2.86
# 861  32872  189.239582  62.308222  3971.875378  5631.527108  3.63   3.37
# 862  32985  189.257820  62.308830  3463.363252  5668.164959  4.59   2.41
# 863  33007  189.240576  62.308991  3944.168281  5677.672075  3.50   3.50
# 864  33024  189.257930  62.309545  3460.315612  5711.066399  8.76  -1.76
# 865  33036  189.258292  62.309209  3450.213204  5690.910974  8.34  -1.34
# 866  33115  189.246243  62.310027  3786.176764  5739.868268  3.61   3.39
# 867  33136  189.256834  62.309815  3490.881000  5727.252837  8.93  -1.93
# 868  33268  189.246283  62.311625  3785.087668  5835.748703  3.50   3.50
# 869  33307  189.243589  62.311654  3860.196145  5837.469768  3.50   3.50
# 870  33422  189.249693  62.312612  3690.036959  5894.997242  3.50   3.50
# 871  33680  189.246824  62.314478  3770.052842  6006.933133  4.21   2.79
# 872  33726  189.247262  62.314544  3757.843805  6010.896616  3.89   3.11
#
# [873 rows x 7 columns]

# %%
def circle_var(gidn, radius, field):
    text1="var circle = L.circle(gid{0}, ".format(gidn)
    
    text2="{\n\
color: 'red',\n\
fillOpacity: 0,\n\
opacity: 0,\n"

    text3="radius:{0}".format(radius)
    
    text4="}).addTo(map);"
    
    text5="circle.bindPopup('gid#{0}: ' + '<a href=".format(gidn)
    
    text6='"bio_pages/{1}_{0}.html" target="_blank">'.format(gidn, field)
    
    text7="BIO PAGE</a>')\n\
circle.on('mouseover', function (e) {"
    
    text8="circlegid='{0}';\n\
document.getElementById('circle_tracker').innerHTML=circlegid".format(gidn)
    
    text9="});\n\
circle.on('mouseout', function (e) {\n\
circlegid='Move cursor over object';\n\
document.getElementById('circle_tracker').innerHTML=circlegid\n\
});"
    
    return text1 + text2 + text3 + text4 + text5 +text6 + text7 + text8 + text9

# %%
gid=GN4data['ids']
radii=GN4data['radii']
        
for i,j in zip(gid, radii):
        variables=circle_var(i,j,'GN4')
        print(variables)
# Out:
# var circle = L.circle(gid14810, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#14810: ' + '<a href="bio_pages/GN4_14810.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='14810';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid14883, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#14883: ' + '<a href="bio_pages/GN4_14883.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='14883';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid15255, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#15255: ' + '<a href="bio_pages/GN4_15255.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='15255';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid15516, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#15516: ' + '<a href="bio_pages/GN4_15516.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='15516';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid15861, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.91}).addTo(map);circle.bindPopup('gid#15861: ' + '<a href="bio_pages/GN4_15861.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='15861';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid15901, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.4}).addTo(map);circle.bindPopup('gid#15901: ' + '<a href="bio_pages/GN4_15901.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='15901';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid15957, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#15957: ' + '<a href="bio_pages/GN4_15957.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='15957';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid15998, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#15998: ' + '<a href="bio_pages/GN4_15998.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='15998';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid15999, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.36}).addTo(map);circle.bindPopup('gid#15999: ' + '<a href="bio_pages/GN4_15999.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='15999';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16083, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#16083: ' + '<a href="bio_pages/GN4_16083.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16083';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16229, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#16229: ' + '<a href="bio_pages/GN4_16229.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16229';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16230, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#16230: ' + '<a href="bio_pages/GN4_16230.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16230';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16286, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#16286: ' + '<a href="bio_pages/GN4_16286.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16286';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16315, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.29}).addTo(map);circle.bindPopup('gid#16315: ' + '<a href="bio_pages/GN4_16315.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16315';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16343, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.46}).addTo(map);circle.bindPopup('gid#16343: ' + '<a href="bio_pages/GN4_16343.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16343';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16469, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.41}).addTo(map);circle.bindPopup('gid#16469: ' + '<a href="bio_pages/GN4_16469.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16469';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16603, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.36}).addTo(map);circle.bindPopup('gid#16603: ' + '<a href="bio_pages/GN4_16603.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16603';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16616, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:1.9000000000000004}).addTo(map);circle.bindPopup('gid#16616: ' + '<a href="bio_pages/GN4_16616.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16616';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16628, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.5}).addTo(map);circle.bindPopup('gid#16628: ' + '<a href="bio_pages/GN4_16628.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16628';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16635, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.22}).addTo(map);circle.bindPopup('gid#16635: ' + '<a href="bio_pages/GN4_16635.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16635';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16674, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.37}).addTo(map);circle.bindPopup('gid#16674: ' + '<a href="bio_pages/GN4_16674.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16674';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16755, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.13}).addTo(map);circle.bindPopup('gid#16755: ' + '<a href="bio_pages/GN4_16755.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16755';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16797, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.6500000000000004}).addTo(map);circle.bindPopup('gid#16797: ' + '<a href="bio_pages/GN4_16797.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16797';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16827, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.35}).addTo(map);circle.bindPopup('gid#16827: ' + '<a href="bio_pages/GN4_16827.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16827';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16883, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#16883: ' + '<a href="bio_pages/GN4_16883.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16883';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16903, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#16903: ' + '<a href="bio_pages/GN4_16903.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16903';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16942, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#16942: ' + '<a href="bio_pages/GN4_16942.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16942';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16945, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#16945: ' + '<a href="bio_pages/GN4_16945.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16945';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid16987, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#16987: ' + '<a href="bio_pages/GN4_16987.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='16987';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17029, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.32}).addTo(map);circle.bindPopup('gid#17029: ' + '<a href="bio_pages/GN4_17029.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17029';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17041, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.33}).addTo(map);circle.bindPopup('gid#17041: ' + '<a href="bio_pages/GN4_17041.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17041';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17070, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#17070: ' + '<a href="bio_pages/GN4_17070.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17070';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17075, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.19}).addTo(map);circle.bindPopup('gid#17075: ' + '<a href="bio_pages/GN4_17075.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17075';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17082, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.21}).addTo(map);circle.bindPopup('gid#17082: ' + '<a href="bio_pages/GN4_17082.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17082';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17098, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.71}).addTo(map);circle.bindPopup('gid#17098: ' + '<a href="bio_pages/GN4_17098.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17098';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17128, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#17128: ' + '<a href="bio_pages/GN4_17128.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17128';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17153, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:1.7400000000000002}).addTo(map);circle.bindPopup('gid#17153: ' + '<a href="bio_pages/GN4_17153.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17153';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17193, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#17193: ' + '<a href="bio_pages/GN4_17193.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17193';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17338, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#17338: ' + '<a href="bio_pages/GN4_17338.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17338';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17433, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#17433: ' + '<a href="bio_pages/GN4_17433.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17433';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17500, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.8499999999999996}).addTo(map);circle.bindPopup('gid#17500: ' + '<a href="bio_pages/GN4_17500.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17500';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17515, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.15}).addTo(map);circle.bindPopup('gid#17515: ' + '<a href="bio_pages/GN4_17515.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17515';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17540, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#17540: ' + '<a href="bio_pages/GN4_17540.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17540';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17560, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.47}).addTo(map);circle.bindPopup('gid#17560: ' + '<a href="bio_pages/GN4_17560.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17560';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17581, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#17581: ' + '<a href="bio_pages/GN4_17581.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17581';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17611, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.22}).addTo(map);circle.bindPopup('gid#17611: ' + '<a href="bio_pages/GN4_17611.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17611';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17708, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:1.5}).addTo(map);circle.bindPopup('gid#17708: ' + '<a href="bio_pages/GN4_17708.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17708';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17712, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.4000000000000004}).addTo(map);circle.bindPopup('gid#17712: ' + '<a href="bio_pages/GN4_17712.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17712';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17758, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#17758: ' + '<a href="bio_pages/GN4_17758.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17758';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17782, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#17782: ' + '<a href="bio_pages/GN4_17782.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17782';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17835, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.38}).addTo(map);circle.bindPopup('gid#17835: ' + '<a href="bio_pages/GN4_17835.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17835';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17891, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.4800000000000004}).addTo(map);circle.bindPopup('gid#17891: ' + '<a href="bio_pages/GN4_17891.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17891';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17892, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.83}).addTo(map);circle.bindPopup('gid#17892: ' + '<a href="bio_pages/GN4_17892.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17892';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17930, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.47}).addTo(map);circle.bindPopup('gid#17930: ' + '<a href="bio_pages/GN4_17930.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17930';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17934, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.7}).addTo(map);circle.bindPopup('gid#17934: ' + '<a href="bio_pages/GN4_17934.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17934';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17937, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.13}).addTo(map);circle.bindPopup('gid#17937: ' + '<a href="bio_pages/GN4_17937.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17937';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17942, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.41}).addTo(map);circle.bindPopup('gid#17942: ' + '<a href="bio_pages/GN4_17942.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17942';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17958, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.24}).addTo(map);circle.bindPopup('gid#17958: ' + '<a href="bio_pages/GN4_17958.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17958';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17974, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.4}).addTo(map);circle.bindPopup('gid#17974: ' + '<a href="bio_pages/GN4_17974.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17974';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid17989, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#17989: ' + '<a href="bio_pages/GN4_17989.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='17989';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18030, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.1}).addTo(map);circle.bindPopup('gid#18030: ' + '<a href="bio_pages/GN4_18030.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18030';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18038, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.16}).addTo(map);circle.bindPopup('gid#18038: ' + '<a href="bio_pages/GN4_18038.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18038';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18043, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#18043: ' + '<a href="bio_pages/GN4_18043.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18043';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18098, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.46}).addTo(map);circle.bindPopup('gid#18098: ' + '<a href="bio_pages/GN4_18098.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18098';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18100, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#18100: ' + '<a href="bio_pages/GN4_18100.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18100';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18101, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.11}).addTo(map);circle.bindPopup('gid#18101: ' + '<a href="bio_pages/GN4_18101.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18101';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18108, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.23}).addTo(map);circle.bindPopup('gid#18108: ' + '<a href="bio_pages/GN4_18108.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18108';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18131, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#18131: ' + '<a href="bio_pages/GN4_18131.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18131';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18139, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#18139: ' + '<a href="bio_pages/GN4_18139.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18139';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18145, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#18145: ' + '<a href="bio_pages/GN4_18145.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18145';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18149, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.79}).addTo(map);circle.bindPopup('gid#18149: ' + '<a href="bio_pages/GN4_18149.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18149';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18163, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.34}).addTo(map);circle.bindPopup('gid#18163: ' + '<a href="bio_pages/GN4_18163.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18163';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18181, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.84}).addTo(map);circle.bindPopup('gid#18181: ' + '<a href="bio_pages/GN4_18181.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18181';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18201, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#18201: ' + '<a href="bio_pages/GN4_18201.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18201';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18205, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.08}).addTo(map);circle.bindPopup('gid#18205: ' + '<a href="bio_pages/GN4_18205.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18205';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18232, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#18232: ' + '<a href="bio_pages/GN4_18232.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18232';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18236, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.03}).addTo(map);circle.bindPopup('gid#18236: ' + '<a href="bio_pages/GN4_18236.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18236';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18289, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.2300000000000004}).addTo(map);circle.bindPopup('gid#18289: ' + '<a href="bio_pages/GN4_18289.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18289';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18291, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.8099999999999996}).addTo(map);circle.bindPopup('gid#18291: ' + '<a href="bio_pages/GN4_18291.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18291';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18364, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#18364: ' + '<a href="bio_pages/GN4_18364.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18364';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18375, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:1.4699999999999998}).addTo(map);circle.bindPopup('gid#18375: ' + '<a href="bio_pages/GN4_18375.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18375';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18400, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#18400: ' + '<a href="bio_pages/GN4_18400.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18400';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18401, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.6399999999999997}).addTo(map);circle.bindPopup('gid#18401: ' + '<a href="bio_pages/GN4_18401.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18401';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18403, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.3}).addTo(map);circle.bindPopup('gid#18403: ' + '<a href="bio_pages/GN4_18403.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18403';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18439, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#18439: ' + '<a href="bio_pages/GN4_18439.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18439';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18457, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.17}).addTo(map);circle.bindPopup('gid#18457: ' + '<a href="bio_pages/GN4_18457.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18457';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18477, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.9800000000000004}).addTo(map);circle.bindPopup('gid#18477: ' + '<a href="bio_pages/GN4_18477.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18477';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18513, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.12}).addTo(map);circle.bindPopup('gid#18513: ' + '<a href="bio_pages/GN4_18513.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18513';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18520, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#18520: ' + '<a href="bio_pages/GN4_18520.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18520';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18523, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:0.9299999999999997}).addTo(map);circle.bindPopup('gid#18523: ' + '<a href="bio_pages/GN4_18523.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18523';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18546, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.35}).addTo(map);circle.bindPopup('gid#18546: ' + '<a href="bio_pages/GN4_18546.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18546';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18558, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#18558: ' + '<a href="bio_pages/GN4_18558.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18558';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18565, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:1.6799999999999997}).addTo(map);circle.bindPopup('gid#18565: ' + '<a href="bio_pages/GN4_18565.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18565';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18574, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#18574: ' + '<a href="bio_pages/GN4_18574.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18574';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18633, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.11}).addTo(map);circle.bindPopup('gid#18633: ' + '<a href="bio_pages/GN4_18633.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18633';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18661, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.42}).addTo(map);circle.bindPopup('gid#18661: ' + '<a href="bio_pages/GN4_18661.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18661';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18662, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#18662: ' + '<a href="bio_pages/GN4_18662.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18662';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18667, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.6799999999999997}).addTo(map);circle.bindPopup('gid#18667: ' + '<a href="bio_pages/GN4_18667.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18667';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18692, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.9299999999999997}).addTo(map);circle.bindPopup('gid#18692: ' + '<a href="bio_pages/GN4_18692.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18692';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18756, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.21}).addTo(map);circle.bindPopup('gid#18756: ' + '<a href="bio_pages/GN4_18756.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18756';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18763, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.04}).addTo(map);circle.bindPopup('gid#18763: ' + '<a href="bio_pages/GN4_18763.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18763';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18767, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.08}).addTo(map);circle.bindPopup('gid#18767: ' + '<a href="bio_pages/GN4_18767.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18767';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18778, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.75}).addTo(map);circle.bindPopup('gid#18778: ' + '<a href="bio_pages/GN4_18778.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='18778';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid18794, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#18794: ' + '<a href="bio_pages/GN4_18794.html" target="_blank">BIO PAGE</a>')
# ...
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31871, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.38}).addTo(map);circle.bindPopup('gid#31871: ' + '<a href="bio_pages/GN4_31871.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31871';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31904, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31904: ' + '<a href="bio_pages/GN4_31904.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31904';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31972, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31972: ' + '<a href="bio_pages/GN4_31972.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31972';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31973, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31973: ' + '<a href="bio_pages/GN4_31973.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31973';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32018, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.6799999999999997}).addTo(map);circle.bindPopup('gid#32018: ' + '<a href="bio_pages/GN4_32018.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32018';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32103, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.9299999999999997}).addTo(map);circle.bindPopup('gid#32103: ' + '<a href="bio_pages/GN4_32103.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32103';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32108, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32108: ' + '<a href="bio_pages/GN4_32108.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32108';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32113, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32113: ' + '<a href="bio_pages/GN4_32113.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32113';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32149, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.26}).addTo(map);circle.bindPopup('gid#32149: ' + '<a href="bio_pages/GN4_32149.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32149';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32229, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32229: ' + '<a href="bio_pages/GN4_32229.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32229';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32250, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.1900000000000004}).addTo(map);circle.bindPopup('gid#32250: ' + '<a href="bio_pages/GN4_32250.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32250';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32309, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.47}).addTo(map);circle.bindPopup('gid#32309: ' + '<a href="bio_pages/GN4_32309.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32309';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32329, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.48}).addTo(map);circle.bindPopup('gid#32329: ' + '<a href="bio_pages/GN4_32329.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32329';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32340, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32340: ' + '<a href="bio_pages/GN4_32340.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32340';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32418, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32418: ' + '<a href="bio_pages/GN4_32418.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32418';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32545, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.42}).addTo(map);circle.bindPopup('gid#32545: ' + '<a href="bio_pages/GN4_32545.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32545';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32606, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.23}).addTo(map);circle.bindPopup('gid#32606: ' + '<a href="bio_pages/GN4_32606.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32606';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32637, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.8600000000000003}).addTo(map);circle.bindPopup('gid#32637: ' + '<a href="bio_pages/GN4_32637.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32637';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32649, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.43}).addTo(map);circle.bindPopup('gid#32649: ' + '<a href="bio_pages/GN4_32649.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32649';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32719, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32719: ' + '<a href="bio_pages/GN4_32719.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32719';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32843, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32843: ' + '<a href="bio_pages/GN4_32843.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32843';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32867, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.8600000000000003}).addTo(map);circle.bindPopup('gid#32867: ' + '<a href="bio_pages/GN4_32867.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32867';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32872, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.37}).addTo(map);circle.bindPopup('gid#32872: ' + '<a href="bio_pages/GN4_32872.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32872';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32985, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.41}).addTo(map);circle.bindPopup('gid#32985: ' + '<a href="bio_pages/GN4_32985.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32985';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid33007, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#33007: ' + '<a href="bio_pages/GN4_33007.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='33007';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid33024, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:-1.7599999999999998}).addTo(map);circle.bindPopup('gid#33024: ' + '<a href="bio_pages/GN4_33024.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='33024';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid33036, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:-1.3399999999999999}).addTo(map);circle.bindPopup('gid#33036: ' + '<a href="bio_pages/GN4_33036.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='33036';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid33115, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.39}).addTo(map);circle.bindPopup('gid#33115: ' + '<a href="bio_pages/GN4_33115.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='33115';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid33136, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:-1.9299999999999997}).addTo(map);circle.bindPopup('gid#33136: ' + '<a href="bio_pages/GN4_33136.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='33136';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid33268, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#33268: ' + '<a href="bio_pages/GN4_33268.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='33268';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid33307, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#33307: ' + '<a href="bio_pages/GN4_33307.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='33307';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid33422, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5}).addTo(map);circle.bindPopup('gid#33422: ' + '<a href="bio_pages/GN4_33422.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='33422';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid33680, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.79}).addTo(map);circle.bindPopup('gid#33680: ' + '<a href="bio_pages/GN4_33680.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='33680';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid33726, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.11}).addTo(map);circle.bindPopup('gid#33726: ' + '<a href="bio_pages/GN4_33726.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='33726';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
