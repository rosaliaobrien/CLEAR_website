# %%
import pandas as pd
import numpy as np
import csv

def cirsize(r):
    return 7-r

GN5data = pd.read_csv('/Users/rosaliaobrien/research/website/website_data/GN5.cat', sep=' ')
GN5data['radii'] = cirsize(GN5data['kr'])
#print(GN5data)

# %%
def circle_var(gidn, radius, field):
    text1="var circle = L.circle(gid{0}, ".format(gidn)
    
    text2="{\n\
color: 'red',\n\
fillOpacity: 0,\n\
weight: 0.8,\n\
opacity: 3,\n"

    text3="radius:{0}".format(radius)
    
    text4="}).addTo(map);"
    
    text5="circle.bindPopup('gid#{0}: ' + '<a href=".format(gidn)
    
    text6='"bio_pages/{1}_{0}.html" target="_blank">'.format(gidn, field)
    
    text7="BIO PAGE</a>')\n\
circle.on('mouseover', function (e) {"
    
    text8="circlegid='{0}';\n\
document.getElementById('circle_tracker').innerHTML=circlegid".format(gidn)
    
    text9="});\n\
circle.on('mouseout', function (e) {\n\
circlegid='Move cursor over object';\n\
document.getElementById('circle_tracker').innerHTML=circlegid\n\
});"
    
    return text1 + text2 + text3 + text4 + text5 +text6 + text7 + text8 + text9

# %%
gid=GN5data['ids']
radii=GN5data['radii']
        
for i,j in zip(gid, radii):
        variables=circle_var(i,j,'GN5')
        print(variables)
# Out:
# var circle = L.circle(gid29743, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.49}).addTo(map);circle.bindPopup('gid#29743: ' + '<a href="bio_pages/GN5_29743.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='29743';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid29993, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.39}).addTo(map);circle.bindPopup('gid#29993: ' + '<a href="bio_pages/GN5_29993.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='29993';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30044, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#30044: ' + '<a href="bio_pages/GN5_30044.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30044';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30084, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#30084: ' + '<a href="bio_pages/GN5_30084.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30084';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30243, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#30243: ' + '<a href="bio_pages/GN5_30243.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30243';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30291, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#30291: ' + '<a href="bio_pages/GN5_30291.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30291';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30296, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#30296: ' + '<a href="bio_pages/GN5_30296.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30296';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30345, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#30345: ' + '<a href="bio_pages/GN5_30345.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30345';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30452, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.42}).addTo(map);circle.bindPopup('gid#30452: ' + '<a href="bio_pages/GN5_30452.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30452';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30564, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.19}).addTo(map);circle.bindPopup('gid#30564: ' + '<a href="bio_pages/GN5_30564.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30564';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30588, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#30588: ' + '<a href="bio_pages/GN5_30588.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30588';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30595, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.59}).addTo(map);circle.bindPopup('gid#30595: ' + '<a href="bio_pages/GN5_30595.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30595';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30739, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#30739: ' + '<a href="bio_pages/GN5_30739.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30739';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30796, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.38}).addTo(map);circle.bindPopup('gid#30796: ' + '<a href="bio_pages/GN5_30796.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30796';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30811, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.35}).addTo(map);circle.bindPopup('gid#30811: ' + '<a href="bio_pages/GN5_30811.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30811';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30876, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.41}).addTo(map);circle.bindPopup('gid#30876: ' + '<a href="bio_pages/GN5_30876.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30876';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30898, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#30898: ' + '<a href="bio_pages/GN5_30898.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30898';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30957, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#30957: ' + '<a href="bio_pages/GN5_30957.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30957';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid30961, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#30961: ' + '<a href="bio_pages/GN5_30961.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='30961';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31050, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31050: ' + '<a href="bio_pages/GN5_31050.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31050';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31056, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.8600000000000003}).addTo(map);circle.bindPopup('gid#31056: ' + '<a href="bio_pages/GN5_31056.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31056';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31088, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.29}).addTo(map);circle.bindPopup('gid#31088: ' + '<a href="bio_pages/GN5_31088.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31088';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31126, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31126: ' + '<a href="bio_pages/GN5_31126.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31126';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31128, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31128: ' + '<a href="bio_pages/GN5_31128.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31128';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31137, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.8899999999999997}).addTo(map);circle.bindPopup('gid#31137: ' + '<a href="bio_pages/GN5_31137.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31137';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31143, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.8099999999999996}).addTo(map);circle.bindPopup('gid#31143: ' + '<a href="bio_pages/GN5_31143.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31143';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31173, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.99}).addTo(map);circle.bindPopup('gid#31173: ' + '<a href="bio_pages/GN5_31173.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31173';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31232, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31232: ' + '<a href="bio_pages/GN5_31232.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31232';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31234, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31234: ' + '<a href="bio_pages/GN5_31234.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31234';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31249, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.58}).addTo(map);circle.bindPopup('gid#31249: ' + '<a href="bio_pages/GN5_31249.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31249';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31257, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.46}).addTo(map);circle.bindPopup('gid#31257: ' + '<a href="bio_pages/GN5_31257.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31257';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31269, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31269: ' + '<a href="bio_pages/GN5_31269.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31269';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31273, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.4400000000000004}).addTo(map);circle.bindPopup('gid#31273: ' + '<a href="bio_pages/GN5_31273.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31273';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31310, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.07}).addTo(map);circle.bindPopup('gid#31310: ' + '<a href="bio_pages/GN5_31310.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31310';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31314, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.92}).addTo(map);circle.bindPopup('gid#31314: ' + '<a href="bio_pages/GN5_31314.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31314';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31371, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31371: ' + '<a href="bio_pages/GN5_31371.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31371';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31381, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31381: ' + '<a href="bio_pages/GN5_31381.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31381';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31383, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.75}).addTo(map);circle.bindPopup('gid#31383: ' + '<a href="bio_pages/GN5_31383.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31383';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31400, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31400: ' + '<a href="bio_pages/GN5_31400.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31400';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31404, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31404: ' + '<a href="bio_pages/GN5_31404.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31404';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31441, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.49}).addTo(map);circle.bindPopup('gid#31441: ' + '<a href="bio_pages/GN5_31441.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31441';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31443, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.44}).addTo(map);circle.bindPopup('gid#31443: ' + '<a href="bio_pages/GN5_31443.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31443';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31481, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31481: ' + '<a href="bio_pages/GN5_31481.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31481';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31525, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.28}).addTo(map);circle.bindPopup('gid#31525: ' + '<a href="bio_pages/GN5_31525.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31525';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31575, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.14}).addTo(map);circle.bindPopup('gid#31575: ' + '<a href="bio_pages/GN5_31575.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31575';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31586, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31586: ' + '<a href="bio_pages/GN5_31586.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31586';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31624, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31624: ' + '<a href="bio_pages/GN5_31624.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31624';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31639, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.03}).addTo(map);circle.bindPopup('gid#31639: ' + '<a href="bio_pages/GN5_31639.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31639';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31682, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.26}).addTo(map);circle.bindPopup('gid#31682: ' + '<a href="bio_pages/GN5_31682.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31682';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31690, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31690: ' + '<a href="bio_pages/GN5_31690.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31690';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31743, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.13}).addTo(map);circle.bindPopup('gid#31743: ' + '<a href="bio_pages/GN5_31743.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31743';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31761, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31761: ' + '<a href="bio_pages/GN5_31761.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31761';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31774, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31774: ' + '<a href="bio_pages/GN5_31774.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31774';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31775, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31775: ' + '<a href="bio_pages/GN5_31775.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31775';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31786, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.38}).addTo(map);circle.bindPopup('gid#31786: ' + '<a href="bio_pages/GN5_31786.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31786';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31789, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31789: ' + '<a href="bio_pages/GN5_31789.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31789';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31790, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31790: ' + '<a href="bio_pages/GN5_31790.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31790';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31804, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.33}).addTo(map);circle.bindPopup('gid#31804: ' + '<a href="bio_pages/GN5_31804.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31804';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31806, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31806: ' + '<a href="bio_pages/GN5_31806.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31806';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31825, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31825: ' + '<a href="bio_pages/GN5_31825.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31825';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31832, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.01}).addTo(map);circle.bindPopup('gid#31832: ' + '<a href="bio_pages/GN5_31832.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31832';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31857, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31857: ' + '<a href="bio_pages/GN5_31857.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31857';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31874, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.9699999999999998}).addTo(map);circle.bindPopup('gid#31874: ' + '<a href="bio_pages/GN5_31874.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31874';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31879, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.36}).addTo(map);circle.bindPopup('gid#31879: ' + '<a href="bio_pages/GN5_31879.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31879';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31887, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.15}).addTo(map);circle.bindPopup('gid#31887: ' + '<a href="bio_pages/GN5_31887.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31887';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31900, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31900: ' + '<a href="bio_pages/GN5_31900.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31900';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31929, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31929: ' + '<a href="bio_pages/GN5_31929.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31929';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31952, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31952: ' + '<a href="bio_pages/GN5_31952.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31952';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31973, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31973: ' + '<a href="bio_pages/GN5_31973.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31973';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31978, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31978: ' + '<a href="bio_pages/GN5_31978.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31978';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31984, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31984: ' + '<a href="bio_pages/GN5_31984.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31984';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid31996, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#31996: ' + '<a href="bio_pages/GN5_31996.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='31996';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32003, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32003: ' + '<a href="bio_pages/GN5_32003.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32003';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32023, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.19}).addTo(map);circle.bindPopup('gid#32023: ' + '<a href="bio_pages/GN5_32023.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32023';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32033, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32033: ' + '<a href="bio_pages/GN5_32033.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32033';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32042, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32042: ' + '<a href="bio_pages/GN5_32042.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32042';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32095, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32095: ' + '<a href="bio_pages/GN5_32095.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32095';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32113, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32113: ' + '<a href="bio_pages/GN5_32113.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32113';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32122, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.27}).addTo(map);circle.bindPopup('gid#32122: ' + '<a href="bio_pages/GN5_32122.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32122';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32135, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32135: ' + '<a href="bio_pages/GN5_32135.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32135';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32146, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32146: ' + '<a href="bio_pages/GN5_32146.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32146';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32157, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32157: ' + '<a href="bio_pages/GN5_32157.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32157';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32162, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32162: ' + '<a href="bio_pages/GN5_32162.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32162';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32175, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.07}).addTo(map);circle.bindPopup('gid#32175: ' + '<a href="bio_pages/GN5_32175.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32175';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32244, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32244: ' + '<a href="bio_pages/GN5_32244.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32244';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32246, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32246: ' + '<a href="bio_pages/GN5_32246.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32246';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32250, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.1900000000000004}).addTo(map);circle.bindPopup('gid#32250: ' + '<a href="bio_pages/GN5_32250.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32250';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32266, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.1500000000000004}).addTo(map);circle.bindPopup('gid#32266: ' + '<a href="bio_pages/GN5_32266.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32266';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32275, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32275: ' + '<a href="bio_pages/GN5_32275.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32275';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32304, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.95}).addTo(map);circle.bindPopup('gid#32304: ' + '<a href="bio_pages/GN5_32304.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32304';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32305, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.25}).addTo(map);circle.bindPopup('gid#32305: ' + '<a href="bio_pages/GN5_32305.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32305';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32329, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.48}).addTo(map);circle.bindPopup('gid#32329: ' + '<a href="bio_pages/GN5_32329.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32329';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32355, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.8200000000000003}).addTo(map);circle.bindPopup('gid#32355: ' + '<a href="bio_pages/GN5_32355.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32355';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32394, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32394: ' + '<a href="bio_pages/GN5_32394.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32394';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32398, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32398: ' + '<a href="bio_pages/GN5_32398.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32398';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32406, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32406: ' + '<a href="bio_pages/GN5_32406.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32406';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32412, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.6799999999999997}).addTo(map);circle.bindPopup('gid#32412: ' + '<a href="bio_pages/GN5_32412.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32412';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32436, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32436: ' + '<a href="bio_pages/GN5_32436.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32436';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32459, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32459: ' + '<a href="bio_pages/GN5_32459.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32459';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32466, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#32466: ' + '<a href="bio_pages/GN5_32466.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32466';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid32478, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.74}).addTo(map);circle.bindPopup('gid#32478: ' + '<a href="bio_pages/GN5_32478.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='32478';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# ...
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35940, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.25}).addTo(map);circle.bindPopup('gid#35940: ' + '<a href="bio_pages/GN5_35940.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35940';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35943, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.4100000000000001}).addTo(map);circle.bindPopup('gid#35943: ' + '<a href="bio_pages/GN5_35943.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35943';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35947, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.8099999999999996}).addTo(map);circle.bindPopup('gid#35947: ' + '<a href="bio_pages/GN5_35947.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35947';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35948, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.26}).addTo(map);circle.bindPopup('gid#35948: ' + '<a href="bio_pages/GN5_35948.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35948';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35965, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.9400000000000004}).addTo(map);circle.bindPopup('gid#35965: ' + '<a href="bio_pages/GN5_35965.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35965';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35977, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.88}).addTo(map);circle.bindPopup('gid#35977: ' + '<a href="bio_pages/GN5_35977.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35977';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35979, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#35979: ' + '<a href="bio_pages/GN5_35979.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35979';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35984, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.66}).addTo(map);circle.bindPopup('gid#35984: ' + '<a href="bio_pages/GN5_35984.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35984';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35986, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.21}).addTo(map);circle.bindPopup('gid#35986: ' + '<a href="bio_pages/GN5_35986.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35986';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35988, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.9800000000000004}).addTo(map);circle.bindPopup('gid#35988: ' + '<a href="bio_pages/GN5_35988.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35988';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35995, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.44}).addTo(map);circle.bindPopup('gid#35995: ' + '<a href="bio_pages/GN5_35995.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35995';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36015, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.09}).addTo(map);circle.bindPopup('gid#36015: ' + '<a href="bio_pages/GN5_36015.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36015';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36022, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#36022: ' + '<a href="bio_pages/GN5_36022.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36022';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36028, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:0.9000000000000004}).addTo(map);circle.bindPopup('gid#36028: ' + '<a href="bio_pages/GN5_36028.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36028';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36047, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.43}).addTo(map);circle.bindPopup('gid#36047: ' + '<a href="bio_pages/GN5_36047.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36047';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36070, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.12}).addTo(map);circle.bindPopup('gid#36070: ' + '<a href="bio_pages/GN5_36070.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36070';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36071, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:-0.13999999999999968}).addTo(map);circle.bindPopup('gid#36071: ' + '<a href="bio_pages/GN5_36071.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36071';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36100, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.4299999999999997}).addTo(map);circle.bindPopup('gid#36100: ' + '<a href="bio_pages/GN5_36100.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36100';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36132, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.9400000000000004}).addTo(map);circle.bindPopup('gid#36132: ' + '<a href="bio_pages/GN5_36132.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36132';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36138, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.46}).addTo(map);circle.bindPopup('gid#36138: ' + '<a href="bio_pages/GN5_36138.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36138';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36145, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.05}).addTo(map);circle.bindPopup('gid#36145: ' + '<a href="bio_pages/GN5_36145.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36145';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36146, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.96}).addTo(map);circle.bindPopup('gid#36146: ' + '<a href="bio_pages/GN5_36146.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36146';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36156, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.37}).addTo(map);circle.bindPopup('gid#36156: ' + '<a href="bio_pages/GN5_36156.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36156';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36161, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#36161: ' + '<a href="bio_pages/GN5_36161.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36161';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36210, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.4000000000000004}).addTo(map);circle.bindPopup('gid#36210: ' + '<a href="bio_pages/GN5_36210.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36210';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36217, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.29}).addTo(map);circle.bindPopup('gid#36217: ' + '<a href="bio_pages/GN5_36217.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36217';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36277, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.8}).addTo(map);circle.bindPopup('gid#36277: ' + '<a href="bio_pages/GN5_36277.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36277';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36327, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.1799999999999997}).addTo(map);circle.bindPopup('gid#36327: ' + '<a href="bio_pages/GN5_36327.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36327';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36341, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.7800000000000002}).addTo(map);circle.bindPopup('gid#36341: ' + '<a href="bio_pages/GN5_36341.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36341';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36397, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.16}).addTo(map);circle.bindPopup('gid#36397: ' + '<a href="bio_pages/GN5_36397.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36397';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36401, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.0099999999999998}).addTo(map);circle.bindPopup('gid#36401: ' + '<a href="bio_pages/GN5_36401.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36401';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36497, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.2199999999999998}).addTo(map);circle.bindPopup('gid#36497: ' + '<a href="bio_pages/GN5_36497.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36497';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36672, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:0.04999999999999982}).addTo(map);circle.bindPopup('gid#36672: ' + '<a href="bio_pages/GN5_36672.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36672';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
