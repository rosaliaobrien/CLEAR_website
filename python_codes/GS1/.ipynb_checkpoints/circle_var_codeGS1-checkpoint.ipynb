# %%
import pandas as pd
import numpy as np
import csv

def cirsize(r):
    return 10-r

GS1data = pd.read_csv('/Users/rosaliaobrien/research/website/website_data/GS1.cat', sep=' ')
GS1data['radii'] = cirsize(GS1data['kr'])
# print(GS1data)

# %%
def circle_var(gidn, radius, field):
    text1="var circle = L.circle(gid{0}, ".format(gidn)
    
    text2="{\n\
color: 'red',\n\
fillOpacity: 0,\n\
weight: 0.8,\n\
opacity: 3,\n"

    text3="radius:{0}".format(radius)
    
    text4="}).addTo(map);"
    
    text5="circle.bindPopup('gid#{0}: ' + '<a href=".format(gidn)
    
    text6='"bio_pages/{1}_{0}.html" target="_blank">'.format(gidn, field)
    
    text7="BIO PAGE</a>')\n\
circle.on('mouseover', function (e) {"
    
    text8="circlegid='{0}';\n\
document.getElementById('circle_tracker').innerHTML=circlegid".format(gidn)
    
    text9="});\n\
circle.on('mouseout', function (e) {\n\
circlegid='Move cursor over object';\n\
document.getElementById('circle_tracker').innerHTML=circlegid\n\
});"
    
    return text1 + text2 + text3 + text4 + text5 +text6 + text7 + text8 + text9

# %%
gid=GS1data['ids']
radii=GS1data['radii']
        
for i,j in zip(gid, radii):
        variables=circle_var(i,j,'GS1')
        print(variables)
# Out:
# var circle = L.circle(gid42861, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#42861: ' + '<a href="bio_pages/GS1_42861.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42861';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43386, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#43386: ' + '<a href="bio_pages/GS1_43386.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43386';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43403, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#43403: ' + '<a href="bio_pages/GS1_43403.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43403';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43812, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#43812: ' + '<a href="bio_pages/GS1_43812.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43812';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43904, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#43904: ' + '<a href="bio_pages/GS1_43904.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43904';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44116, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#44116: ' + '<a href="bio_pages/GS1_44116.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44116';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44135, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#44135: ' + '<a href="bio_pages/GS1_44135.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44135';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44225, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#44225: ' + '<a href="bio_pages/GS1_44225.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44225';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44288, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#44288: ' + '<a href="bio_pages/GS1_44288.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44288';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44311, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#44311: ' + '<a href="bio_pages/GS1_44311.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44311';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44427, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#44427: ' + '<a href="bio_pages/GS1_44427.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44427';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44999, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#44999: ' + '<a href="bio_pages/GS1_44999.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44999';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45242, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#45242: ' + '<a href="bio_pages/GS1_45242.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45242';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45264, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:5.6}).addTo(map);circle.bindPopup('gid#45264: ' + '<a href="bio_pages/GS1_45264.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45264';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45273, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#45273: ' + '<a href="bio_pages/GS1_45273.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45273';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45364, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#45364: ' + '<a href="bio_pages/GS1_45364.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45364';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45424, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#45424: ' + '<a href="bio_pages/GS1_45424.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45424';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45485, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.46}).addTo(map);circle.bindPopup('gid#45485: ' + '<a href="bio_pages/GS1_45485.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45485';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45574, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#45574: ' + '<a href="bio_pages/GS1_45574.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45574';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45591, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#45591: ' + '<a href="bio_pages/GS1_45591.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45591';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45752, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#45752: ' + '<a href="bio_pages/GS1_45752.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45752';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45789, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#45789: ' + '<a href="bio_pages/GS1_45789.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45789';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45816, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#45816: ' + '<a href="bio_pages/GS1_45816.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45816';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45915, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#45915: ' + '<a href="bio_pages/GS1_45915.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45915';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid46356, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#46356: ' + '<a href="bio_pages/GS1_46356.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='46356';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid46386, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#46386: ' + '<a href="bio_pages/GS1_46386.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='46386';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid46881, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#46881: ' + '<a href="bio_pages/GS1_46881.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='46881';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid46922, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#46922: ' + '<a href="bio_pages/GS1_46922.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='46922';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid46932, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#46932: ' + '<a href="bio_pages/GS1_46932.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='46932';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid47121, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#47121: ' + '<a href="bio_pages/GS1_47121.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='47121';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid47214, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#47214: ' + '<a href="bio_pages/GS1_47214.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='47214';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid47219, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#47219: ' + '<a href="bio_pages/GS1_47219.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='47219';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid47421, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#47421: ' + '<a href="bio_pages/GS1_47421.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='47421';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid47469, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#47469: ' + '<a href="bio_pages/GS1_47469.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='47469';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid47487, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#47487: ' + '<a href="bio_pages/GS1_47487.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='47487';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid47580, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#47580: ' + '<a href="bio_pages/GS1_47580.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='47580';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid47691, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#47691: ' + '<a href="bio_pages/GS1_47691.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='47691';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid47746, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#47746: ' + '<a href="bio_pages/GS1_47746.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='47746';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid48793, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#48793: ' + '<a href="bio_pages/GS1_48793.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='48793';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid48850, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#48850: ' + '<a href="bio_pages/GS1_48850.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='48850';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid48918, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#48918: ' + '<a href="bio_pages/GS1_48918.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='48918';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49040, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49040: ' + '<a href="bio_pages/GS1_49040.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49040';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49046, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49046: ' + '<a href="bio_pages/GS1_49046.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49046';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49053, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49053: ' + '<a href="bio_pages/GS1_49053.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49053';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49063, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.43}).addTo(map);circle.bindPopup('gid#49063: ' + '<a href="bio_pages/GS1_49063.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49063';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49100, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49100: ' + '<a href="bio_pages/GS1_49100.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49100';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49105, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49105: ' + '<a href="bio_pages/GS1_49105.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49105';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49132, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49132: ' + '<a href="bio_pages/GS1_49132.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49132';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49194, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49194: ' + '<a href="bio_pages/GS1_49194.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49194';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49209, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.32}).addTo(map);circle.bindPopup('gid#49209: ' + '<a href="bio_pages/GS1_49209.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49209';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49247, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.43}).addTo(map);circle.bindPopup('gid#49247: ' + '<a href="bio_pages/GS1_49247.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49247';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49330, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49330: ' + '<a href="bio_pages/GS1_49330.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49330';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49340, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49340: ' + '<a href="bio_pages/GS1_49340.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49340';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49346, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49346: ' + '<a href="bio_pages/GS1_49346.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49346';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49377, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49377: ' + '<a href="bio_pages/GS1_49377.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49377';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49402, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49402: ' + '<a href="bio_pages/GS1_49402.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49402';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49426, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49426: ' + '<a href="bio_pages/GS1_49426.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49426';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49466, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49466: ' + '<a href="bio_pages/GS1_49466.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49466';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49493, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49493: ' + '<a href="bio_pages/GS1_49493.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49493';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49501, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49501: ' + '<a href="bio_pages/GS1_49501.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49501';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49504, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49504: ' + '<a href="bio_pages/GS1_49504.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49504';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49554, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49554: ' + '<a href="bio_pages/GS1_49554.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49554';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49597, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49597: ' + '<a href="bio_pages/GS1_49597.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49597';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49609, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49609: ' + '<a href="bio_pages/GS1_49609.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49609';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49612, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49612: ' + '<a href="bio_pages/GS1_49612.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49612';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49662, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49662: ' + '<a href="bio_pages/GS1_49662.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49662';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49669, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49669: ' + '<a href="bio_pages/GS1_49669.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49669';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49691, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49691: ' + '<a href="bio_pages/GS1_49691.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49691';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49693, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49693: ' + '<a href="bio_pages/GS1_49693.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49693';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49702, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49702: ' + '<a href="bio_pages/GS1_49702.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49702';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49718, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49718: ' + '<a href="bio_pages/GS1_49718.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49718';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49720, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49720: ' + '<a href="bio_pages/GS1_49720.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49720';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49728, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49728: ' + '<a href="bio_pages/GS1_49728.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49728';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49742, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49742: ' + '<a href="bio_pages/GS1_49742.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49742';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49780, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49780: ' + '<a href="bio_pages/GS1_49780.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49780';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49836, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49836: ' + '<a href="bio_pages/GS1_49836.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49836';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49837, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:5.62}).addTo(map);circle.bindPopup('gid#49837: ' + '<a href="bio_pages/GS1_49837.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49837';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49838, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49838: ' + '<a href="bio_pages/GS1_49838.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49838';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49872, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49872: ' + '<a href="bio_pages/GS1_49872.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49872';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49874, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49874: ' + '<a href="bio_pages/GS1_49874.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49874';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49888, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.29}).addTo(map);circle.bindPopup('gid#49888: ' + '<a href="bio_pages/GS1_49888.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49888';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49891, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49891: ' + '<a href="bio_pages/GS1_49891.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49891';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49896, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49896: ' + '<a href="bio_pages/GS1_49896.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49896';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49904, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49904: ' + '<a href="bio_pages/GS1_49904.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49904';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49955, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#49955: ' + '<a href="bio_pages/GS1_49955.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49955';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid50110, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#50110: ' + '<a href="bio_pages/GS1_50110.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='50110';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid50214, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#50214: ' + '<a href="bio_pages/GS1_50214.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='50214';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid50249, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:6.5}).addTo(map);circle.bindPopup('gid#50249: ' + '<a href="bio_pages/GS1_50249.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='50249';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid50292, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:5.89}).addTo(map);circle.bindPopup('gid#50292: ' + '<a href="bio_pages/GS1_50292.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='50292';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid50389, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.6899999999999995}).addTo(map);circle.bindPopup('gid#50389: ' + '<a href="bio_pages/GS1_50389.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='50389';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
