# %%
import pandas as pd
import numpy as np
import csv

def cirsize(r):
    return 8-r

GS2data = pd.read_csv('/Users/rosaliaobrien/research/website_data/GS2.cat', sep=' ')
GS2data['radii'] = cirsize(GS2data['kr'])
print(GS2data)
# Out:
#        ids         ra        dec            x            y    kr  radii
# 0    41965  53.141417 -27.714113  1091.021744    20.988387  3.50   4.50
# 1    42185  53.138362 -27.705886  1253.230848   514.632233  3.50   4.50
# 2    42471  53.122445 -27.712005  2098.754057   147.543777  4.81   3.19
# 3    42472  53.122068 -27.712458  2118.779328   120.363630  3.50   4.50
# 4    42504  53.123503 -27.711823  2042.555323   158.463702  3.50   4.50
# 5    42520  53.126369 -27.711246  1890.318342   193.081087  3.70   4.30
# 6    42576  53.125352 -27.711913  1944.340402   153.062352  3.50   4.50
# 7    42652  53.126815 -27.711208  1866.627548   195.360354  4.00   4.00
# 8    42706  53.122824 -27.711195  2078.622369   196.143915  3.89   4.11
# 9    42711  53.126478 -27.710848  1884.527733   216.960974  4.44   3.56
# 10   42762  53.120572 -27.710841  2198.244995   217.382946  3.50   4.50
# 11   42788  53.143497 -27.710568   980.502861   233.671238  4.21   3.79
# 12   42820  53.142135 -27.711249  1052.856759   192.822916  4.37   3.63
# 13   42822  53.141234 -27.710542  1100.709878   235.250377  3.50   4.50
# 14   42915  53.138677 -27.709999  1236.529786   267.849426  3.50   4.50
# 15   42956  53.129288 -27.710163  1735.262849   258.054861  3.58   4.42
# 16   42981  53.131458 -27.709355  1619.991763   306.527856  3.65   4.35
# 17   43018  53.127035 -27.709548  1854.938066   294.960211  3.50   4.50
# 18   43028  53.130530 -27.709570  1669.287130   293.631120  3.50   4.50
# 19   43048  53.131798 -27.709743  1601.932974   283.246494  3.52   4.48
# 20   43071  53.122589 -27.707908  2091.105413   393.364420  3.50   4.50
# 21   43126  53.142630 -27.708707  1026.538563   345.339121  3.50   4.50
# 22   43144  53.143376 -27.708930   986.913702   331.952573  3.50   4.50
# 23   43262  53.133931 -27.709016  1488.626309   326.857308  3.50   4.50
# 24   43264  53.135733 -27.708434  1392.901651   361.768016  3.84   4.16
# 25   43266  53.142836 -27.706936  1015.578581   451.597635  3.50   4.50
# 26   43283  53.135500 -27.708069  1405.276240   383.669366  4.03   3.97
# 27   43342  53.144194 -27.706711   943.438839   465.085518  3.50   4.50
# 28   43352  53.129559 -27.707407  1720.858507   423.414516  3.50   4.50
# 29   43356  53.139191 -27.708473  1209.214461   359.406080  3.50   4.50
# ..     ...        ...        ...          ...          ...   ...    ...
# 305  49400  53.142370 -27.676676  1040.042648  2267.208460  4.74   3.26
# 306  49401  53.127101 -27.675133  1851.359081  2359.867737  3.52   4.48
# 307  49411  53.130364 -27.675651  1677.978749  2328.779176  3.50   4.50
# 308  49441  53.129911 -27.671553  1702.034839  2574.661865  3.50   4.50
# 309  49526  53.136752 -27.675279  1338.546045  2351.069550  3.73   4.27
# 310  49542  53.149554 -27.675718   658.307579  2324.616916  3.85   4.15
# 311  49555  53.129166 -27.675200  1741.633774  2355.842929  3.75   4.25
# 312  49626  53.127771 -27.674779  1815.757198  2381.106490  4.24   3.76
# 313  49661  53.141206 -27.673884  1101.866728  2434.738837  3.81   4.19
# 314  49682  53.144728 -27.674044   914.721840  2425.108120  3.50   4.50
# 315  49692  53.147710 -27.672189   756.246535  2536.378551  3.50   4.50
# 316  49712  53.148637 -27.674244   707.014254  2413.067765  5.15   2.85
# 317  49763  53.145921 -27.672954   851.317801  2490.496855  3.59   4.41
# 318  49771  53.140584 -27.672981  1134.909738  2488.923974  3.76   4.24
# 319  49790  53.140889 -27.673148  1118.704464  2478.901560  3.50   4.50
# 320  49809  53.134455 -27.673169  1460.586855  2477.682903  4.15   3.85
# 321  49834  53.138508 -27.671789  1245.212763  2560.459363  3.68   4.32
# 322  49845  53.133370 -27.672253  1518.235536  2532.648402  4.46   3.54
# 323  49864  53.141587 -27.672069  1081.605037  2543.636337  3.83   4.17
# 324  49881  53.128244 -27.672201  1790.616944  2535.786204  4.29   3.71
# 325  49902  53.137562 -27.671316  1295.477396  2588.845739  3.60   4.40
# 326  49927  53.130589 -27.671668  1666.007991  2567.759639  7.59   0.41
# 327  49939  53.131724 -27.671159  1605.694656  2598.295690  3.50   4.50
# 328  50010  53.131143 -27.669909  1636.562585  2673.298262  3.88   4.12
# 329  50039  53.130205 -27.669938  1686.406506  2671.561453  3.87   4.13
# 330  50040  53.131015 -27.670092  1643.365039  2662.318662  6.33   1.67
# 331  50073  53.131718 -27.669018  1606.004105  2726.756402  4.51   3.49
# 332  50147  53.140452 -27.668814  1141.887778  2738.946313  3.83   4.17
# 333  50288  53.138803 -27.669540  1229.519571  2695.398061  3.59   4.41
# 334  50425  53.132926 -27.669670  1541.815637  2687.631210  3.81   4.19
#
# [335 rows x 7 columns]

# %%
def circle_var(gidn, radius, field):
    text1="var circle = L.circle(gid{0}, ".format(gidn)
    
    text2="{\n\
color: 'red',\n\
fillOpacity: 0,\n\
opacity: 0,\n"

    text3="radius:{0}".format(radius)
    
    text4="}).addTo(map);"
    
    text5="circle.bindPopup('gid#{0}: ' + '<a href=".format(gidn)
    
    text6='"bio_pages/{1}_{0}.html" target="_blank">'.format(gidn, field)
    
    text7="BIO PAGE</a>')\n\
circle.on('mouseover', function (e) {"
    
    text8="circlegid='{0}';\n\
document.getElementById('circle_tracker').innerHTML=circlegid".format(gidn)
    
    text9="});\n\
circle.on('mouseout', function (e) {\n\
circlegid='Move cursor over object';\n\
document.getElementById('circle_tracker').innerHTML=circlegid\n\
});"
    
    return text1 + text2 + text3 + text4 + text5 +text6 + text7 + text8 + text9

# %%
gid=GS2data['ids']
radii=GS2data['radii']
        
for i,j in zip(gid, radii):
        variables=circle_var(i,j,'GS2')
        print(variables)
# Out:
# var circle = L.circle(gid41965, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#41965: ' + '<a href="bio_pages/GS2_41965.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='41965';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42185, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42185: ' + '<a href="bio_pages/GS2_42185.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42185';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42471, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.1900000000000004}).addTo(map);circle.bindPopup('gid#42471: ' + '<a href="bio_pages/GS2_42471.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42471';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42472, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42472: ' + '<a href="bio_pages/GS2_42472.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42472';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42504, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42504: ' + '<a href="bio_pages/GS2_42504.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42504';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42520, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.3}).addTo(map);circle.bindPopup('gid#42520: ' + '<a href="bio_pages/GS2_42520.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42520';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42576, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42576: ' + '<a href="bio_pages/GS2_42576.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42576';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42652, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.0}).addTo(map);circle.bindPopup('gid#42652: ' + '<a href="bio_pages/GS2_42652.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42652';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42706, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.109999999999999}).addTo(map);circle.bindPopup('gid#42706: ' + '<a href="bio_pages/GS2_42706.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42706';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42711, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5599999999999996}).addTo(map);circle.bindPopup('gid#42711: ' + '<a href="bio_pages/GS2_42711.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42711';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42762, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42762: ' + '<a href="bio_pages/GS2_42762.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42762';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42788, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.79}).addTo(map);circle.bindPopup('gid#42788: ' + '<a href="bio_pages/GS2_42788.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42788';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42820, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.63}).addTo(map);circle.bindPopup('gid#42820: ' + '<a href="bio_pages/GS2_42820.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42820';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42822, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42822: ' + '<a href="bio_pages/GS2_42822.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42822';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42915, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42915: ' + '<a href="bio_pages/GS2_42915.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42915';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42956, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.42}).addTo(map);circle.bindPopup('gid#42956: ' + '<a href="bio_pages/GS2_42956.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42956';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42981, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.35}).addTo(map);circle.bindPopup('gid#42981: ' + '<a href="bio_pages/GS2_42981.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42981';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43018, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43018: ' + '<a href="bio_pages/GS2_43018.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43018';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43028, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43028: ' + '<a href="bio_pages/GS2_43028.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43028';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43048, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.48}).addTo(map);circle.bindPopup('gid#43048: ' + '<a href="bio_pages/GS2_43048.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43048';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43071, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43071: ' + '<a href="bio_pages/GS2_43071.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43071';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43126, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43126: ' + '<a href="bio_pages/GS2_43126.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43126';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43144, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43144: ' + '<a href="bio_pages/GS2_43144.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43144';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43262, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43262: ' + '<a href="bio_pages/GS2_43262.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43262';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43264, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.16}).addTo(map);circle.bindPopup('gid#43264: ' + '<a href="bio_pages/GS2_43264.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43264';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43266, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43266: ' + '<a href="bio_pages/GS2_43266.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43266';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43283, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.9699999999999998}).addTo(map);circle.bindPopup('gid#43283: ' + '<a href="bio_pages/GS2_43283.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43283';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43342, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43342: ' + '<a href="bio_pages/GS2_43342.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43342';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43352, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43352: ' + '<a href="bio_pages/GS2_43352.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43352';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43356, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43356: ' + '<a href="bio_pages/GS2_43356.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43356';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43401, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43401: ' + '<a href="bio_pages/GS2_43401.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43401';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43417, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43417: ' + '<a href="bio_pages/GS2_43417.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43417';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43548, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43548: ' + '<a href="bio_pages/GS2_43548.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43548';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43567, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43567: ' + '<a href="bio_pages/GS2_43567.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43567';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43572, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.42}).addTo(map);circle.bindPopup('gid#43572: ' + '<a href="bio_pages/GS2_43572.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43572';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43581, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.29}).addTo(map);circle.bindPopup('gid#43581: ' + '<a href="bio_pages/GS2_43581.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43581';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43596, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.9800000000000004}).addTo(map);circle.bindPopup('gid#43596: ' + '<a href="bio_pages/GS2_43596.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43596';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43618, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.66}).addTo(map);circle.bindPopup('gid#43618: ' + '<a href="bio_pages/GS2_43618.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43618';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43651, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.18}).addTo(map);circle.bindPopup('gid#43651: ' + '<a href="bio_pages/GS2_43651.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43651';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43659, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.99}).addTo(map);circle.bindPopup('gid#43659: ' + '<a href="bio_pages/GS2_43659.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43659';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43727, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43727: ' + '<a href="bio_pages/GS2_43727.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43727';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43762, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.34}).addTo(map);circle.bindPopup('gid#43762: ' + '<a href="bio_pages/GS2_43762.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43762';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43809, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43809: ' + '<a href="bio_pages/GS2_43809.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43809';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43926, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43926: ' + '<a href="bio_pages/GS2_43926.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43926';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44020, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.359999999999999}).addTo(map);circle.bindPopup('gid#44020: ' + '<a href="bio_pages/GS2_44020.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44020';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44050, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44050: ' + '<a href="bio_pages/GS2_44050.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44050';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44083, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44083: ' + '<a href="bio_pages/GS2_44083.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44083';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44085, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44085: ' + '<a href="bio_pages/GS2_44085.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44085';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44091, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.4699999999999998}).addTo(map);circle.bindPopup('gid#44091: ' + '<a href="bio_pages/GS2_44091.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44091';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44152, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.8499999999999996}).addTo(map);circle.bindPopup('gid#44152: ' + '<a href="bio_pages/GS2_44152.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44152';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44166, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44166: ' + '<a href="bio_pages/GS2_44166.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44166';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44228, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44228: ' + '<a href="bio_pages/GS2_44228.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44228';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44263, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.33}).addTo(map);circle.bindPopup('gid#44263: ' + '<a href="bio_pages/GS2_44263.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44263';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44402, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.83}).addTo(map);circle.bindPopup('gid#44402: ' + '<a href="bio_pages/GS2_44402.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44402';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44459, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44459: ' + '<a href="bio_pages/GS2_44459.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44459';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44496, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.75}).addTo(map);circle.bindPopup('gid#44496: ' + '<a href="bio_pages/GS2_44496.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44496';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44588, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44588: ' + '<a href="bio_pages/GS2_44588.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44588';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44598, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44598: ' + '<a href="bio_pages/GS2_44598.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44598';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44619, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44619: ' + '<a href="bio_pages/GS2_44619.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44619';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44643, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44643: ' + '<a href="bio_pages/GS2_44643.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44643';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44674, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44674: ' + '<a href="bio_pages/GS2_44674.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44674';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44711, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44711: ' + '<a href="bio_pages/GS2_44711.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44711';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44740, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44740: ' + '<a href="bio_pages/GS2_44740.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44740';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44767, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44767: ' + '<a href="bio_pages/GS2_44767.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44767';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44773, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44773: ' + '<a href="bio_pages/GS2_44773.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44773';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44810, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44810: ' + '<a href="bio_pages/GS2_44810.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44810';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44824, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44824: ' + '<a href="bio_pages/GS2_44824.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44824';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44842, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44842: ' + '<a href="bio_pages/GS2_44842.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44842';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44843, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:1.1900000000000004}).addTo(map);circle.bindPopup('gid#44843: ' + '<a href="bio_pages/GS2_44843.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44843';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44848, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.23}).addTo(map);circle.bindPopup('gid#44848: ' + '<a href="bio_pages/GS2_44848.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44848';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44871, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.17}).addTo(map);circle.bindPopup('gid#44871: ' + '<a href="bio_pages/GS2_44871.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44871';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44920, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.37}).addTo(map);circle.bindPopup('gid#44920: ' + '<a href="bio_pages/GS2_44920.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44920';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44959, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44959: ' + '<a href="bio_pages/GS2_44959.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44959';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44974, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.43}).addTo(map);circle.bindPopup('gid#44974: ' + '<a href="bio_pages/GS2_44974.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44974';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44985, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44985: ' + '<a href="bio_pages/GS2_44985.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44985';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44996, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44996: ' + '<a href="bio_pages/GS2_44996.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44996';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45012, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45012: ' + '<a href="bio_pages/GS2_45012.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45012';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45068, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45068: ' + '<a href="bio_pages/GS2_45068.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45068';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45116, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45116: ' + '<a href="bio_pages/GS2_45116.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45116';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45124, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45124: ' + '<a href="bio_pages/GS2_45124.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45124';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45133, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45133: ' + '<a href="bio_pages/GS2_45133.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45133';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45222, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45222: ' + '<a href="bio_pages/GS2_45222.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45222';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45246, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.9000000000000004}).addTo(map);circle.bindPopup('gid#45246: ' + '<a href="bio_pages/GS2_45246.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45246';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45250, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.7800000000000002}).addTo(map);circle.bindPopup('gid#45250: ' + '<a href="bio_pages/GS2_45250.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45250';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45257, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45257: ' + '<a href="bio_pages/GS2_45257.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45257';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45265, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45265: ' + '<a href="bio_pages/GS2_45265.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45265';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45279, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45279: ' + '<a href="bio_pages/GS2_45279.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45279';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45295, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45295: ' + '<a href="bio_pages/GS2_45295.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45295';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45313, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45313: ' + '<a href="bio_pages/GS2_45313.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45313';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45329, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45329: ' + '<a href="bio_pages/GS2_45329.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45329';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45333, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45333: ' + '<a href="bio_pages/GS2_45333.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45333';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45378, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45378: ' + '<a href="bio_pages/GS2_45378.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45378';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45414, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45414: ' + '<a href="bio_pages/GS2_45414.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45414';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45439, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45439: ' + '<a href="bio_pages/GS2_45439.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45439';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45464, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45464: ' + '<a href="bio_pages/GS2_45464.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45464';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45474, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45474: ' + '<a href="bio_pages/GS2_45474.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45474';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45492, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45492: ' + '<a href="bio_pages/GS2_45492.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45492';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45495, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45495: ' + '<a href="bio_pages/GS2_45495.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45495';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45518, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45518: ' + '<a href="bio_pages/GS2_45518.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45518';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45531, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45531: ' + '<a href="bio_pages/GS2_45531.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45531';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45532, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.5999999999999996}).addTo(map);circle.bindPopup('gid#45532: ' + '<a href="bio_pages/GS2_45532.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45532';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45597, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45597: ' + '<a href="bio_pages/GS2_45597.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45597';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45609, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.5700000000000003}).addTo(map);circle.bindPopup('gid#45609: ' + '<a href="bio_pages/GS2_45609.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45609';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45633, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45633: ' + '<a href="bio_pages/GS2_45633.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45633';
# ...
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49233, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#49233: ' + '<a href="bio_pages/GS2_49233.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49233';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49269, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.35}).addTo(map);circle.bindPopup('gid#49269: ' + '<a href="bio_pages/GS2_49269.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49269';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49320, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.34}).addTo(map);circle.bindPopup('gid#49320: ' + '<a href="bio_pages/GS2_49320.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49320';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49362, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#49362: ' + '<a href="bio_pages/GS2_49362.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49362';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49400, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.26}).addTo(map);circle.bindPopup('gid#49400: ' + '<a href="bio_pages/GS2_49400.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49400';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49401, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.48}).addTo(map);circle.bindPopup('gid#49401: ' + '<a href="bio_pages/GS2_49401.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49401';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49411, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#49411: ' + '<a href="bio_pages/GS2_49411.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49411';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49441, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#49441: ' + '<a href="bio_pages/GS2_49441.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49441';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49526, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.27}).addTo(map);circle.bindPopup('gid#49526: ' + '<a href="bio_pages/GS2_49526.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49526';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49542, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.15}).addTo(map);circle.bindPopup('gid#49542: ' + '<a href="bio_pages/GS2_49542.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49542';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49555, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.25}).addTo(map);circle.bindPopup('gid#49555: ' + '<a href="bio_pages/GS2_49555.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49555';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49626, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.76}).addTo(map);circle.bindPopup('gid#49626: ' + '<a href="bio_pages/GS2_49626.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49626';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49661, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.1899999999999995}).addTo(map);circle.bindPopup('gid#49661: ' + '<a href="bio_pages/GS2_49661.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49661';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49682, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#49682: ' + '<a href="bio_pages/GS2_49682.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49682';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49692, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#49692: ' + '<a href="bio_pages/GS2_49692.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49692';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49712, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:2.8499999999999996}).addTo(map);circle.bindPopup('gid#49712: ' + '<a href="bio_pages/GS2_49712.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49712';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49763, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.41}).addTo(map);circle.bindPopup('gid#49763: ' + '<a href="bio_pages/GS2_49763.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49763';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49771, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.24}).addTo(map);circle.bindPopup('gid#49771: ' + '<a href="bio_pages/GS2_49771.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49771';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49790, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#49790: ' + '<a href="bio_pages/GS2_49790.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49790';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49809, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.8499999999999996}).addTo(map);circle.bindPopup('gid#49809: ' + '<a href="bio_pages/GS2_49809.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49809';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49834, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.32}).addTo(map);circle.bindPopup('gid#49834: ' + '<a href="bio_pages/GS2_49834.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49834';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49845, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.54}).addTo(map);circle.bindPopup('gid#49845: ' + '<a href="bio_pages/GS2_49845.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49845';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49864, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.17}).addTo(map);circle.bindPopup('gid#49864: ' + '<a href="bio_pages/GS2_49864.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49864';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49881, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.71}).addTo(map);circle.bindPopup('gid#49881: ' + '<a href="bio_pages/GS2_49881.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49881';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49902, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.4}).addTo(map);circle.bindPopup('gid#49902: ' + '<a href="bio_pages/GS2_49902.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49902';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49927, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:0.41000000000000014}).addTo(map);circle.bindPopup('gid#49927: ' + '<a href="bio_pages/GS2_49927.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49927';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid49939, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.5}).addTo(map);circle.bindPopup('gid#49939: ' + '<a href="bio_pages/GS2_49939.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='49939';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid50010, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.12}).addTo(map);circle.bindPopup('gid#50010: ' + '<a href="bio_pages/GS2_50010.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='50010';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid50039, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.13}).addTo(map);circle.bindPopup('gid#50039: ' + '<a href="bio_pages/GS2_50039.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='50039';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid50040, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:1.67}).addTo(map);circle.bindPopup('gid#50040: ' + '<a href="bio_pages/GS2_50040.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='50040';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid50073, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:3.49}).addTo(map);circle.bindPopup('gid#50073: ' + '<a href="bio_pages/GS2_50073.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='50073';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid50147, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.17}).addTo(map);circle.bindPopup('gid#50147: ' + '<a href="bio_pages/GS2_50147.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='50147';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid50288, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.41}).addTo(map);circle.bindPopup('gid#50288: ' + '<a href="bio_pages/GS2_50288.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='50288';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid50425, {
# color: 'red',
# fillOpacity: 0,
# opacity: 0,
# radius:4.1899999999999995}).addTo(map);circle.bindPopup('gid#50425: ' + '<a href="bio_pages/GS2_50425.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='50425';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
