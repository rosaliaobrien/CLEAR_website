# %%
import pandas as pd
import numpy as np
import csv

def cirsize(r):
    return 8-r

GS3data = pd.read_csv('/Users/rosaliaobrien/research/website/website_data_old/GS3.cat', sep=' ')
GS3data['radii'] = cirsize(GS3data['kr'])
print(GS3data)
# Out:
#        ids         ra        dec            x            y    kr  radii
# 0    34082  53.145185 -27.751049  2020.282383    91.791724  3.90   4.10
# 1    34359  53.157904 -27.752224  1344.939317    21.133635  3.50   4.50
# 2    34363  53.151279 -27.749884  1696.682263   161.624771  3.50   4.50
# 3    34418  53.150246 -27.752242  1751.565548    20.157150  3.50   4.50
# 4    34482  53.145440 -27.750533  2006.736479   122.749264  3.50   4.50
# ..     ...        ...        ...          ...          ...   ...    ...
# 339  43007  53.146974 -27.709766  1924.800210  2568.757660  3.95   4.05
# 340  43210  53.157430 -27.709016  1369.375917  2613.625029  3.53   4.47
# 341  43248  53.155747 -27.708315  1458.764408  2655.709694  3.50   4.50
# 342  43631  53.153674 -27.707181  1568.864304  2723.778442  3.50   4.50
# 343  43638  53.150370 -27.706840  1744.368837  2744.280189  3.76   4.24
#
# [344 rows x 7 columns]

# %%
def circle_var(gidn, radius, field):
    text1="var circle = L.circle(gid{0}, ".format(gidn)
    
    text2="{\n\
color: 'red',\n\
fillOpacity: 0,\n\
weight: 0.8,\n\
opacity: 3,\n"

    text3="radius:{0}".format(radius)
    
    text4="}).addTo(map);"
    
    text5="circle.bindPopup('gid#{0}: ' + '<a href=".format(gidn)
    
    text6='"bio_pages/{1}_{0}.html" target="_blank">'.format(gidn, field)
    
    text7="BIO PAGE</a>')\n\
circle.on('mouseover', function (e) {"
    
    text8="circlegid='{0}';\n\
document.getElementById('circle_tracker').innerHTML=circlegid".format(gidn)
    
    text9="});\n\
circle.on('mouseout', function (e) {\n\
circlegid='Move cursor over object';\n\
document.getElementById('circle_tracker').innerHTML=circlegid\n\
});"
    
    return text1 + text2 + text3 + text4 + text5 +text6 + text7 + text8 + text9

# %%
gid=GS3data['ids']
radii=GS3data['radii']
        
for i,j in zip(gid, radii):
        variables=circle_var(i,j,'GS3')
        print(variables)
# Out:
# var circle = L.circle(gid34082, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.1}).addTo(map);circle.bindPopup('gid#34082: ' + '<a href="bio_pages/GS3_34082.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='34082';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid34359, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#34359: ' + '<a href="bio_pages/GS3_34359.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='34359';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid34363, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#34363: ' + '<a href="bio_pages/GS3_34363.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='34363';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid34418, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#34418: ' + '<a href="bio_pages/GS3_34418.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='34418';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid34482, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#34482: ' + '<a href="bio_pages/GS3_34482.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='34482';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid34518, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.43}).addTo(map);circle.bindPopup('gid#34518: ' + '<a href="bio_pages/GS3_34518.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='34518';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid34543, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.18}).addTo(map);circle.bindPopup('gid#34543: ' + '<a href="bio_pages/GS3_34543.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='34543';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid34627, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#34627: ' + '<a href="bio_pages/GS3_34627.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='34627';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid34671, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#34671: ' + '<a href="bio_pages/GS3_34671.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='34671';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid34672, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.9000000000000004}).addTo(map);circle.bindPopup('gid#34672: ' + '<a href="bio_pages/GS3_34672.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='34672';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid34682, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#34682: ' + '<a href="bio_pages/GS3_34682.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='34682';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid34716, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#34716: ' + '<a href="bio_pages/GS3_34716.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='34716';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid34968, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.7699999999999996}).addTo(map);circle.bindPopup('gid#34968: ' + '<a href="bio_pages/GS3_34968.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='34968';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35048, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.37}).addTo(map);circle.bindPopup('gid#35048: ' + '<a href="bio_pages/GS3_35048.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35048';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35111, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#35111: ' + '<a href="bio_pages/GS3_35111.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35111';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35137, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#35137: ' + '<a href="bio_pages/GS3_35137.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35137';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35145, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.38}).addTo(map);circle.bindPopup('gid#35145: ' + '<a href="bio_pages/GS3_35145.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35145';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35193, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.87}).addTo(map);circle.bindPopup('gid#35193: ' + '<a href="bio_pages/GS3_35193.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35193';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35332, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#35332: ' + '<a href="bio_pages/GS3_35332.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35332';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35420, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#35420: ' + '<a href="bio_pages/GS3_35420.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35420';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35433, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#35433: ' + '<a href="bio_pages/GS3_35433.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35433';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35444, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#35444: ' + '<a href="bio_pages/GS3_35444.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35444';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35475, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.92}).addTo(map);circle.bindPopup('gid#35475: ' + '<a href="bio_pages/GS3_35475.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35475';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35484, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#35484: ' + '<a href="bio_pages/GS3_35484.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35484';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35539, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#35539: ' + '<a href="bio_pages/GS3_35539.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35539';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35587, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.37}).addTo(map);circle.bindPopup('gid#35587: ' + '<a href="bio_pages/GS3_35587.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35587';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35642, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.26}).addTo(map);circle.bindPopup('gid#35642: ' + '<a href="bio_pages/GS3_35642.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35642';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35719, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#35719: ' + '<a href="bio_pages/GS3_35719.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35719';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35721, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#35721: ' + '<a href="bio_pages/GS3_35721.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35721';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35747, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#35747: ' + '<a href="bio_pages/GS3_35747.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35747';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35758, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.3499999999999996}).addTo(map);circle.bindPopup('gid#35758: ' + '<a href="bio_pages/GS3_35758.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35758';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35774, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#35774: ' + '<a href="bio_pages/GS3_35774.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35774';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35800, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.49}).addTo(map);circle.bindPopup('gid#35800: ' + '<a href="bio_pages/GS3_35800.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35800';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35826, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.1399999999999997}).addTo(map);circle.bindPopup('gid#35826: ' + '<a href="bio_pages/GS3_35826.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35826';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35937, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.29}).addTo(map);circle.bindPopup('gid#35937: ' + '<a href="bio_pages/GS3_35937.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35937';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid35993, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#35993: ' + '<a href="bio_pages/GS3_35993.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35993';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36000, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.13}).addTo(map);circle.bindPopup('gid#36000: ' + '<a href="bio_pages/GS3_36000.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36000';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36001, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36001: ' + '<a href="bio_pages/GS3_36001.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36001';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36009, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.3}).addTo(map);circle.bindPopup('gid#36009: ' + '<a href="bio_pages/GS3_36009.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36009';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36066, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.66}).addTo(map);circle.bindPopup('gid#36066: ' + '<a href="bio_pages/GS3_36066.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36066';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36095, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.21}).addTo(map);circle.bindPopup('gid#36095: ' + '<a href="bio_pages/GS3_36095.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36095';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36096, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.7199999999999998}).addTo(map);circle.bindPopup('gid#36096: ' + '<a href="bio_pages/GS3_36096.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36096';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36126, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36126: ' + '<a href="bio_pages/GS3_36126.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36126';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36127, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.41}).addTo(map);circle.bindPopup('gid#36127: ' + '<a href="bio_pages/GS3_36127.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36127';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36178, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36178: ' + '<a href="bio_pages/GS3_36178.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36178';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36182, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.16}).addTo(map);circle.bindPopup('gid#36182: ' + '<a href="bio_pages/GS3_36182.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36182';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36207, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:2.96}).addTo(map);circle.bindPopup('gid#36207: ' + '<a href="bio_pages/GS3_36207.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36207';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36220, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36220: ' + '<a href="bio_pages/GS3_36220.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36220';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36249, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36249: ' + '<a href="bio_pages/GS3_36249.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36249';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36303, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:1.3399999999999999}).addTo(map);circle.bindPopup('gid#36303: ' + '<a href="bio_pages/GS3_36303.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36303';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36316, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36316: ' + '<a href="bio_pages/GS3_36316.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36316';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36366, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36366: ' + '<a href="bio_pages/GS3_36366.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36366';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36376, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.8600000000000003}).addTo(map);circle.bindPopup('gid#36376: ' + '<a href="bio_pages/GS3_36376.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36376';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36451, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36451: ' + '<a href="bio_pages/GS3_36451.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36451';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36459, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.390000000000001}).addTo(map);circle.bindPopup('gid#36459: ' + '<a href="bio_pages/GS3_36459.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36459';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36482, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36482: ' + '<a href="bio_pages/GS3_36482.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36482';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36509, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36509: ' + '<a href="bio_pages/GS3_36509.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36509';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36570, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36570: ' + '<a href="bio_pages/GS3_36570.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36570';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36572, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36572: ' + '<a href="bio_pages/GS3_36572.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36572';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36573, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.2800000000000002}).addTo(map);circle.bindPopup('gid#36573: ' + '<a href="bio_pages/GS3_36573.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36573';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36602, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.46}).addTo(map);circle.bindPopup('gid#36602: ' + '<a href="bio_pages/GS3_36602.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36602';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36632, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36632: ' + '<a href="bio_pages/GS3_36632.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36632';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36648, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.95}).addTo(map);circle.bindPopup('gid#36648: ' + '<a href="bio_pages/GS3_36648.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36648';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36652, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.33}).addTo(map);circle.bindPopup('gid#36652: ' + '<a href="bio_pages/GS3_36652.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36652';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36653, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36653: ' + '<a href="bio_pages/GS3_36653.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36653';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36659, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.41}).addTo(map);circle.bindPopup('gid#36659: ' + '<a href="bio_pages/GS3_36659.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36659';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36674, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.1899999999999995}).addTo(map);circle.bindPopup('gid#36674: ' + '<a href="bio_pages/GS3_36674.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36674';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36696, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36696: ' + '<a href="bio_pages/GS3_36696.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36696';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36820, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.9000000000000004}).addTo(map);circle.bindPopup('gid#36820: ' + '<a href="bio_pages/GS3_36820.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36820';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36822, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36822: ' + '<a href="bio_pages/GS3_36822.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36822';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36832, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36832: ' + '<a href="bio_pages/GS3_36832.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36832';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36850, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36850: ' + '<a href="bio_pages/GS3_36850.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36850';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36852, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36852: ' + '<a href="bio_pages/GS3_36852.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36852';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36854, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36854: ' + '<a href="bio_pages/GS3_36854.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36854';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36883, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.48}).addTo(map);circle.bindPopup('gid#36883: ' + '<a href="bio_pages/GS3_36883.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36883';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36971, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36971: ' + '<a href="bio_pages/GS3_36971.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36971';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36972, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36972: ' + '<a href="bio_pages/GS3_36972.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36972';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36979, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.1899999999999995}).addTo(map);circle.bindPopup('gid#36979: ' + '<a href="bio_pages/GS3_36979.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36979';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36997, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.54}).addTo(map);circle.bindPopup('gid#36997: ' + '<a href="bio_pages/GS3_36997.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36997';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37001, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37001: ' + '<a href="bio_pages/GS3_37001.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37001';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37010, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.24}).addTo(map);circle.bindPopup('gid#37010: ' + '<a href="bio_pages/GS3_37010.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37010';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37027, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.140000000000001}).addTo(map);circle.bindPopup('gid#37027: ' + '<a href="bio_pages/GS3_37027.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37027';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37043, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37043: ' + '<a href="bio_pages/GS3_37043.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37043';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37063, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.220000000000001}).addTo(map);circle.bindPopup('gid#37063: ' + '<a href="bio_pages/GS3_37063.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37063';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37082, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.279999999999999}).addTo(map);circle.bindPopup('gid#37082: ' + '<a href="bio_pages/GS3_37082.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37082';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37085, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37085: ' + '<a href="bio_pages/GS3_37085.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37085';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37089, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.140000000000001}).addTo(map);circle.bindPopup('gid#37089: ' + '<a href="bio_pages/GS3_37089.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37089';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37098, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.79}).addTo(map);circle.bindPopup('gid#37098: ' + '<a href="bio_pages/GS3_37098.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37098';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37142, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37142: ' + '<a href="bio_pages/GS3_37142.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37142';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37162, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.029999999999999}).addTo(map);circle.bindPopup('gid#37162: ' + '<a href="bio_pages/GS3_37162.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37162';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37170, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37170: ' + '<a href="bio_pages/GS3_37170.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37170';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37172, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.9400000000000004}).addTo(map);circle.bindPopup('gid#37172: ' + '<a href="bio_pages/GS3_37172.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37172';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37183, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.4399999999999995}).addTo(map);circle.bindPopup('gid#37183: ' + '<a href="bio_pages/GS3_37183.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37183';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37188, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37188: ' + '<a href="bio_pages/GS3_37188.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37188';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37189, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37189: ' + '<a href="bio_pages/GS3_37189.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37189';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37197, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.25}).addTo(map);circle.bindPopup('gid#37197: ' + '<a href="bio_pages/GS3_37197.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37197';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37222, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.49}).addTo(map);circle.bindPopup('gid#37222: ' + '<a href="bio_pages/GS3_37222.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37222';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37249, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37249: ' + '<a href="bio_pages/GS3_37249.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37249';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37256, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37256: ' + '<a href="bio_pages/GS3_37256.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37256';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37259, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.34}).addTo(map);circle.bindPopup('gid#37259: ' + '<a href="bio_pages/GS3_37259.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37259';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37270, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37270: ' + '<a href="bio_pages/GS3_37270.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37270';
# ...
# circle.on('mouseover', function (e) {circlegid='41982';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid41999, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.84}).addTo(map);circle.bindPopup('gid#41999: ' + '<a href="bio_pages/GS3_41999.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='41999';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42032, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.9400000000000004}).addTo(map);circle.bindPopup('gid#42032: ' + '<a href="bio_pages/GS3_42032.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42032';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42038, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.45}).addTo(map);circle.bindPopup('gid#42038: ' + '<a href="bio_pages/GS3_42038.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42038';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42048, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42048: ' + '<a href="bio_pages/GS3_42048.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42048';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42051, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.25}).addTo(map);circle.bindPopup('gid#42051: ' + '<a href="bio_pages/GS3_42051.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42051';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42057, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42057: ' + '<a href="bio_pages/GS3_42057.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42057';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42068, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42068: ' + '<a href="bio_pages/GS3_42068.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42068';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42105, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42105: ' + '<a href="bio_pages/GS3_42105.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42105';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42113, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42113: ' + '<a href="bio_pages/GS3_42113.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42113';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42235, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.33}).addTo(map);circle.bindPopup('gid#42235: ' + '<a href="bio_pages/GS3_42235.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42235';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42236, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.13}).addTo(map);circle.bindPopup('gid#42236: ' + '<a href="bio_pages/GS3_42236.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42236';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42249, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.4399999999999995}).addTo(map);circle.bindPopup('gid#42249: ' + '<a href="bio_pages/GS3_42249.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42249';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42263, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42263: ' + '<a href="bio_pages/GS3_42263.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42263';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42316, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42316: ' + '<a href="bio_pages/GS3_42316.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42316';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42348, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.43}).addTo(map);circle.bindPopup('gid#42348: ' + '<a href="bio_pages/GS3_42348.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42348';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42429, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42429: ' + '<a href="bio_pages/GS3_42429.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42429';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42455, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42455: ' + '<a href="bio_pages/GS3_42455.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42455';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42513, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42513: ' + '<a href="bio_pages/GS3_42513.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42513';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42548, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.7199999999999998}).addTo(map);circle.bindPopup('gid#42548: ' + '<a href="bio_pages/GS3_42548.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42548';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42555, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42555: ' + '<a href="bio_pages/GS3_42555.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42555';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42593, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42593: ' + '<a href="bio_pages/GS3_42593.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42593';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42607, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42607: ' + '<a href="bio_pages/GS3_42607.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42607';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42689, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.02}).addTo(map);circle.bindPopup('gid#42689: ' + '<a href="bio_pages/GS3_42689.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42689';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42778, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42778: ' + '<a href="bio_pages/GS3_42778.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42778';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42866, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42866: ' + '<a href="bio_pages/GS3_42866.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42866';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42903, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:3.0999999999999996}).addTo(map);circle.bindPopup('gid#42903: ' + '<a href="bio_pages/GS3_42903.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42903';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42913, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#42913: ' + '<a href="bio_pages/GS3_42913.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42913';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid42930, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.390000000000001}).addTo(map);circle.bindPopup('gid#42930: ' + '<a href="bio_pages/GS3_42930.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='42930';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43007, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.05}).addTo(map);circle.bindPopup('gid#43007: ' + '<a href="bio_pages/GS3_43007.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43007';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43210, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.470000000000001}).addTo(map);circle.bindPopup('gid#43210: ' + '<a href="bio_pages/GS3_43210.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43210';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43248, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43248: ' + '<a href="bio_pages/GS3_43248.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43248';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43631, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#43631: ' + '<a href="bio_pages/GS3_43631.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43631';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid43638, {
# color: 'red',
# fillOpacity: 0,
# weight: 0.8,
# opacity: 3,
# radius:4.24}).addTo(map);circle.bindPopup('gid#43638: ' + '<a href="bio_pages/GS3_43638.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='43638';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
