# %%
import pandas as pd
import numpy as np
import csv

def cirsize(r):
    return 8-r

GS5data = pd.read_csv('/Users/rosaliaobrien/research/website/website_data_old/GS5.cat', sep=' ')
GS5data['radii'] = cirsize(GS5data['kr'])
print(GS5data)
# Out:
#        ids         ra        dec            x            y    kr  radii
# 0    35688  53.113268 -27.737910  1387.096405   211.221644  3.50   4.50
# 1    36183  53.120075 -27.732122  1025.617022   558.519947  3.50   4.50
# 2    36224  53.104561 -27.734216  1849.516031   432.809957  3.50   4.50
# 3    36394  53.107301 -27.741090  1703.951013    20.389339  3.76   4.24
# 4    36583  53.114498 -27.738177  1321.775959   195.206331  4.25   3.75
# ..     ...        ...        ...          ...          ...   ...    ...
# 381  45972  53.115984 -27.693568  1243.009315  2871.757245  3.50   4.50
# 382  46064  53.117533 -27.695402  1160.711168  2761.720857  3.50   4.50
# 383  46186  53.118898 -27.694766  1088.195453  2799.883658  3.50   4.50
# 384  46216  53.116811 -27.694081  1199.071931  2840.979399  3.81   4.19
# 385  46379  53.114990 -27.692820  1295.820229  2916.634296  3.79   4.21
#
# [386 rows x 7 columns]

# %%
def circle_var(gidn, radius, field):
    text1="var circle = L.circle(gid{0}, ".format(gidn)
    
    text2="{\n\
color: 'red',\n\
fillOpacity: 0,\n\
weight:0.8,\n\
opacity: 3,\n"

    text3="radius:{0}".format(radius)
    
    text4="}).addTo(map);"
    
    text5="circle.bindPopup('gid#{0}: ' + '<a href=".format(gidn)
    
    text6='"bio_pages/{1}_{0}.html" target="_blank">'.format(gidn, field)
    
    text7="BIO PAGE</a>')\n\
circle.on('mouseover', function (e) {"
    
    text8="circlegid='{0}';\n\
document.getElementById('circle_tracker').innerHTML=circlegid".format(gidn)
    
    text9="});\n\
circle.on('mouseout', function (e) {\n\
circlegid='Move cursor over object';\n\
document.getElementById('circle_tracker').innerHTML=circlegid\n\
});"
    
    return text1 + text2 + text3 + text4 + text5 +text6 + text7 + text8 + text9

# %%
gid=GS5data['ids']
radii=GS5data['radii']
        
for i,j in zip(gid, radii):
        variables=circle_var(i,j,'GS5')
        print(variables)
# Out:
# var circle = L.circle(gid35688, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#35688: ' + '<a href="bio_pages/GS5_35688.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='35688';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36183, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36183: ' + '<a href="bio_pages/GS5_36183.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36183';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36224, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36224: ' + '<a href="bio_pages/GS5_36224.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36224';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36394, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.24}).addTo(map);circle.bindPopup('gid#36394: ' + '<a href="bio_pages/GS5_36394.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36394';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36583, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.75}).addTo(map);circle.bindPopup('gid#36583: ' + '<a href="bio_pages/GS5_36583.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36583';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid36932, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#36932: ' + '<a href="bio_pages/GS5_36932.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='36932';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37080, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37080: ' + '<a href="bio_pages/GS5_37080.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37080';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37092, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37092: ' + '<a href="bio_pages/GS5_37092.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37092';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37110, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37110: ' + '<a href="bio_pages/GS5_37110.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37110';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37111, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37111: ' + '<a href="bio_pages/GS5_37111.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37111';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37243, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37243: ' + '<a href="bio_pages/GS5_37243.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37243';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37254, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37254: ' + '<a href="bio_pages/GS5_37254.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37254';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37289, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37289: ' + '<a href="bio_pages/GS5_37289.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37289';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37302, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37302: ' + '<a href="bio_pages/GS5_37302.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37302';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37383, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37383: ' + '<a href="bio_pages/GS5_37383.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37383';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37385, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:2.1799999999999997}).addTo(map);circle.bindPopup('gid#37385: ' + '<a href="bio_pages/GS5_37385.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37385';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37447, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37447: ' + '<a href="bio_pages/GS5_37447.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37447';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37462, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.87}).addTo(map);circle.bindPopup('gid#37462: ' + '<a href="bio_pages/GS5_37462.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37462';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37479, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.67}).addTo(map);circle.bindPopup('gid#37479: ' + '<a href="bio_pages/GS5_37479.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37479';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37485, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37485: ' + '<a href="bio_pages/GS5_37485.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37485';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37542, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37542: ' + '<a href="bio_pages/GS5_37542.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37542';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37625, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.8}).addTo(map);circle.bindPopup('gid#37625: ' + '<a href="bio_pages/GS5_37625.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37625';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37637, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37637: ' + '<a href="bio_pages/GS5_37637.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37637';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37711, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37711: ' + '<a href="bio_pages/GS5_37711.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37711';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37715, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37715: ' + '<a href="bio_pages/GS5_37715.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37715';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37785, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37785: ' + '<a href="bio_pages/GS5_37785.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37785';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37816, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37816: ' + '<a href="bio_pages/GS5_37816.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37816';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37822, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37822: ' + '<a href="bio_pages/GS5_37822.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37822';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37861, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:2.4000000000000004}).addTo(map);circle.bindPopup('gid#37861: ' + '<a href="bio_pages/GS5_37861.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37861';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37885, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37885: ' + '<a href="bio_pages/GS5_37885.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37885';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37937, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37937: ' + '<a href="bio_pages/GS5_37937.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37937';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid37986, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#37986: ' + '<a href="bio_pages/GS5_37986.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='37986';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38014, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:2.84}).addTo(map);circle.bindPopup('gid#38014: ' + '<a href="bio_pages/GS5_38014.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38014';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38060, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38060: ' + '<a href="bio_pages/GS5_38060.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38060';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38076, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.41}).addTo(map);circle.bindPopup('gid#38076: ' + '<a href="bio_pages/GS5_38076.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38076';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38083, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38083: ' + '<a href="bio_pages/GS5_38083.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38083';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38092, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38092: ' + '<a href="bio_pages/GS5_38092.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38092';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38119, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38119: ' + '<a href="bio_pages/GS5_38119.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38119';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38121, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.33}).addTo(map);circle.bindPopup('gid#38121: ' + '<a href="bio_pages/GS5_38121.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38121';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38141, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:2.12}).addTo(map);circle.bindPopup('gid#38141: ' + '<a href="bio_pages/GS5_38141.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38141';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38171, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.41}).addTo(map);circle.bindPopup('gid#38171: ' + '<a href="bio_pages/GS5_38171.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38171';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38202, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38202: ' + '<a href="bio_pages/GS5_38202.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38202';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38216, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.24}).addTo(map);circle.bindPopup('gid#38216: ' + '<a href="bio_pages/GS5_38216.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38216';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38233, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38233: ' + '<a href="bio_pages/GS5_38233.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38233';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38240, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38240: ' + '<a href="bio_pages/GS5_38240.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38240';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38362, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.42}).addTo(map);circle.bindPopup('gid#38362: ' + '<a href="bio_pages/GS5_38362.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38362';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38378, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:-0.14000000000000057}).addTo(map);circle.bindPopup('gid#38378: ' + '<a href="bio_pages/GS5_38378.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38378';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38383, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38383: ' + '<a href="bio_pages/GS5_38383.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38383';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38414, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.59}).addTo(map);circle.bindPopup('gid#38414: ' + '<a href="bio_pages/GS5_38414.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38414';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38436, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.76}).addTo(map);circle.bindPopup('gid#38436: ' + '<a href="bio_pages/GS5_38436.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38436';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38477, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38477: ' + '<a href="bio_pages/GS5_38477.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38477';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38490, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.15}).addTo(map);circle.bindPopup('gid#38490: ' + '<a href="bio_pages/GS5_38490.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38490';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38513, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38513: ' + '<a href="bio_pages/GS5_38513.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38513';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38537, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.4399999999999995}).addTo(map);circle.bindPopup('gid#38537: ' + '<a href="bio_pages/GS5_38537.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38537';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38559, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38559: ' + '<a href="bio_pages/GS5_38559.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38559';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38616, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38616: ' + '<a href="bio_pages/GS5_38616.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38616';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38625, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38625: ' + '<a href="bio_pages/GS5_38625.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38625';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38626, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38626: ' + '<a href="bio_pages/GS5_38626.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38626';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38636, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38636: ' + '<a href="bio_pages/GS5_38636.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38636';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38645, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.84}).addTo(map);circle.bindPopup('gid#38645: ' + '<a href="bio_pages/GS5_38645.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38645';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38671, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38671: ' + '<a href="bio_pages/GS5_38671.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38671';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38684, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.46}).addTo(map);circle.bindPopup('gid#38684: ' + '<a href="bio_pages/GS5_38684.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38684';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38715, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38715: ' + '<a href="bio_pages/GS5_38715.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38715';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38718, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.25}).addTo(map);circle.bindPopup('gid#38718: ' + '<a href="bio_pages/GS5_38718.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38718';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38786, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38786: ' + '<a href="bio_pages/GS5_38786.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38786';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38811, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.5}).addTo(map);circle.bindPopup('gid#38811: ' + '<a href="bio_pages/GS5_38811.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38811';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38833, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.220000000000001}).addTo(map);circle.bindPopup('gid#38833: ' + '<a href="bio_pages/GS5_38833.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38833';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38843, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38843: ' + '<a href="bio_pages/GS5_38843.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38843';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38849, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#38849: ' + '<a href="bio_pages/GS5_38849.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38849';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38873, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.38}).addTo(map);circle.bindPopup('gid#38873: ' + '<a href="bio_pages/GS5_38873.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38873';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38932, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.27}).addTo(map);circle.bindPopup('gid#38932: ' + '<a href="bio_pages/GS5_38932.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38932';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38977, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.8200000000000003}).addTo(map);circle.bindPopup('gid#38977: ' + '<a href="bio_pages/GS5_38977.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38977';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid38982, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.26}).addTo(map);circle.bindPopup('gid#38982: ' + '<a href="bio_pages/GS5_38982.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='38982';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39007, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.41}).addTo(map);circle.bindPopup('gid#39007: ' + '<a href="bio_pages/GS5_39007.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39007';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39015, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#39015: ' + '<a href="bio_pages/GS5_39015.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39015';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39023, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#39023: ' + '<a href="bio_pages/GS5_39023.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39023';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39065, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.08}).addTo(map);circle.bindPopup('gid#39065: ' + '<a href="bio_pages/GS5_39065.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39065';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39097, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#39097: ' + '<a href="bio_pages/GS5_39097.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39097';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39133, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.24}).addTo(map);circle.bindPopup('gid#39133: ' + '<a href="bio_pages/GS5_39133.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39133';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39138, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.29}).addTo(map);circle.bindPopup('gid#39138: ' + '<a href="bio_pages/GS5_39138.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39138';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39171, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.8499999999999996}).addTo(map);circle.bindPopup('gid#39171: ' + '<a href="bio_pages/GS5_39171.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39171';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39176, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#39176: ' + '<a href="bio_pages/GS5_39176.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39176';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39194, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:1.0700000000000003}).addTo(map);circle.bindPopup('gid#39194: ' + '<a href="bio_pages/GS5_39194.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39194';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39231, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#39231: ' + '<a href="bio_pages/GS5_39231.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39231';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39253, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.43}).addTo(map);circle.bindPopup('gid#39253: ' + '<a href="bio_pages/GS5_39253.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39253';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39255, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.08}).addTo(map);circle.bindPopup('gid#39255: ' + '<a href="bio_pages/GS5_39255.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39255';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39283, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.04}).addTo(map);circle.bindPopup('gid#39283: ' + '<a href="bio_pages/GS5_39283.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39283';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39344, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#39344: ' + '<a href="bio_pages/GS5_39344.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39344';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39430, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.21}).addTo(map);circle.bindPopup('gid#39430: ' + '<a href="bio_pages/GS5_39430.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39430';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39438, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#39438: ' + '<a href="bio_pages/GS5_39438.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39438';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39449, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#39449: ' + '<a href="bio_pages/GS5_39449.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39449';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39504, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#39504: ' + '<a href="bio_pages/GS5_39504.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39504';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39591, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#39591: ' + '<a href="bio_pages/GS5_39591.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39591';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39603, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#39603: ' + '<a href="bio_pages/GS5_39603.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39603';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39604, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#39604: ' + '<a href="bio_pages/GS5_39604.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39604';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39636, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#39636: ' + '<a href="bio_pages/GS5_39636.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39636';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39654, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#39654: ' + '<a href="bio_pages/GS5_39654.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39654';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39681, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#39681: ' + '<a href="bio_pages/GS5_39681.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39681';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39690, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.42}).addTo(map);circle.bindPopup('gid#39690: ' + '<a href="bio_pages/GS5_39690.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39690';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39765, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#39765: ' + '<a href="bio_pages/GS5_39765.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39765';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39800, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.49}).addTo(map);circle.bindPopup('gid#39800: ' + '<a href="bio_pages/GS5_39800.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='39800';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid39815, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# ...
# circle.on('mouseover', function (e) {circlegid='44909';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44996, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#44996: ' + '<a href="bio_pages/GS5_44996.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44996';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid44997, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:1.4699999999999998}).addTo(map);circle.bindPopup('gid#44997: ' + '<a href="bio_pages/GS5_44997.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='44997';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45024, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45024: ' + '<a href="bio_pages/GS5_45024.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45024';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45032, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45032: ' + '<a href="bio_pages/GS5_45032.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45032';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45095, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.42}).addTo(map);circle.bindPopup('gid#45095: ' + '<a href="bio_pages/GS5_45095.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45095';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45171, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45171: ' + '<a href="bio_pages/GS5_45171.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45171';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45250, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.7800000000000002}).addTo(map);circle.bindPopup('gid#45250: ' + '<a href="bio_pages/GS5_45250.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45250';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45313, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45313: ' + '<a href="bio_pages/GS5_45313.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45313';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45337, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45337: ' + '<a href="bio_pages/GS5_45337.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45337';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45357, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45357: ' + '<a href="bio_pages/GS5_45357.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45357';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45361, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45361: ' + '<a href="bio_pages/GS5_45361.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45361';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45402, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.8600000000000003}).addTo(map);circle.bindPopup('gid#45402: ' + '<a href="bio_pages/GS5_45402.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45402';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45414, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45414: ' + '<a href="bio_pages/GS5_45414.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45414';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45472, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45472: ' + '<a href="bio_pages/GS5_45472.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45472';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45474, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45474: ' + '<a href="bio_pages/GS5_45474.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45474';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45492, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45492: ' + '<a href="bio_pages/GS5_45492.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45492';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45532, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.5999999999999996}).addTo(map);circle.bindPopup('gid#45532: ' + '<a href="bio_pages/GS5_45532.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45532';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45592, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45592: ' + '<a href="bio_pages/GS5_45592.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45592';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45597, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45597: ' + '<a href="bio_pages/GS5_45597.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45597';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45647, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45647: ' + '<a href="bio_pages/GS5_45647.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45647';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45650, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45650: ' + '<a href="bio_pages/GS5_45650.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45650';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45657, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:3.9400000000000004}).addTo(map);circle.bindPopup('gid#45657: ' + '<a href="bio_pages/GS5_45657.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45657';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45717, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.37}).addTo(map);circle.bindPopup('gid#45717: ' + '<a href="bio_pages/GS5_45717.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45717';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45738, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45738: ' + '<a href="bio_pages/GS5_45738.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45738';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45787, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45787: ' + '<a href="bio_pages/GS5_45787.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45787';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45788, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45788: ' + '<a href="bio_pages/GS5_45788.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45788';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45795, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45795: ' + '<a href="bio_pages/GS5_45795.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45795';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45802, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45802: ' + '<a href="bio_pages/GS5_45802.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45802';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid45972, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#45972: ' + '<a href="bio_pages/GS5_45972.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='45972';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid46064, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#46064: ' + '<a href="bio_pages/GS5_46064.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='46064';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid46186, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.5}).addTo(map);circle.bindPopup('gid#46186: ' + '<a href="bio_pages/GS5_46186.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='46186';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid46216, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.1899999999999995}).addTo(map);circle.bindPopup('gid#46216: ' + '<a href="bio_pages/GS5_46216.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='46216';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
# var circle = L.circle(gid46379, {
# color: 'red',
# fillOpacity: 0,
# weight:0.8,
# opacity: 3,
# radius:4.21}).addTo(map);circle.bindPopup('gid#46379: ' + '<a href="bio_pages/GS5_46379.html" target="_blank">BIO PAGE</a>')
# circle.on('mouseover', function (e) {circlegid='46379';
# document.getElementById('circle_tracker').innerHTML=circlegid});
# circle.on('mouseout', function (e) {
# circlegid='Move cursor over object';
# document.getElementById('circle_tracker').innerHTML=circlegid
# });
